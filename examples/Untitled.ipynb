# %%
import meerkat as mk

# %%
# %load_ext autoreload
# %autoreload 2

# %%
db = mk.get("ngoa")
# Out:
# /home/sabri/code/meerkat/meerkat/datapanel.py:424: DtypeWarning: Columns (28) have mixed types. Specify dtype option on import or set low_memory=False.
#   return cls.from_pandas(pd.read_csv(filepath, *args, **kwargs))

# %%
dp = db["objects"].merge(db["published_images"], left_on="objectid", right_on="depictstmsobjectid")

# %%
from domino import embed 

emb_dp = embed(
    dp.lz[:20_000],
    input_col="image",
    encoder="clip",
    num_workers=7,
    device=0
)
# Out:
#   0%|          | 0/157 [00:00<?, ?it/s]

# %%
emb_dp["image", "title", "beginyear", "medium"][40:50]
# Out:
# DataPanel(nrows: 10, ncols: 4)

# %%
from meerkat.columns.file_column import Downloader

dp["image"] = mk.ImageColumn.from_filepaths(
    dp["iiifthumburl"], loader=Downloader(cache_dir=os.path.join(base_dir, "iiifthumburl"))
)

# %%
db = mk.get("ngoa")
# Out:
# [autoreload of meerkat.datasets.coco failed: Traceback (most recent call last):
#   File "/home/common/miniconda3/envs/meerkat9/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/common/miniconda3/envs/meerkat9/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "/home/common/miniconda3/envs/meerkat9/lib/python3.9/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 613, in _exec
#   File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "/home/sabri/code/meerkat/meerkat/datasets/coco/__init__.py", line 22, in <module>
#     class coco(DatasetBuilder):
#   File "/home/sabri/code/meerkat/meerkat/datasets/registry.py", line 46, in deco
# ...

# %%
mk.get("coco")
# Out:
# [autoreload of meerkat.datasets.coco failed: Traceback (most recent call last):
#   File "/home/common/miniconda3/envs/meerkat9/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/common/miniconda3/envs/meerkat9/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "/home/common/miniconda3/envs/meerkat9/lib/python3.9/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 613, in _exec
#   File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "/home/sabri/code/meerkat/meerkat/datasets/coco/__init__.py", line 22, in <module>
#     class coco(DatasetBuilder):
#   File "/home/sabri/code/meerkat/meerkat/datasets/registry.py", line 46, in deco
# ...
