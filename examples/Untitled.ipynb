# %%
import meerkat as mk
mk.config.datasets.root_dir = "/oak/stanford/groups/jamesz/common/datasets"

# %%
dp = mk.get("imagenet")
dp
# Out:
# DataPanel(nrows: 1331167, ncols: 7)

# %%
dp = mk.get("imagenette", version="160px")
# Out:
# Downloading:   0%|          | 0.00/99.0M [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 dp = mk.get("imagenette", version="160px")
#
# File ~/code/meerkat/meerkat/datasets/__init__.py:67, in get(name, dataset_dir, version, download_mode, registry, **kwargs)
#      65 if registry == "meerkat":
#      66     try:
# ---> 67         dataset = datasets.get(
#      68             name=name,
#      69             dataset_dir=dataset_dir,
#      70             version=version,
#      71             download_mode=download_mode,
#      72             **kwargs,
#      73         )
#      74         return dataset
#      75     except KeyError as e:
#
# File ~/code/meerkat/meerkat/datasets/registry.py:28, in Registry.get(self, name, **kwargs)
#      23 if ret is None:
#      24     raise KeyError(
# ...

# %%
dp = mk.get("imagenette", version="320px")
