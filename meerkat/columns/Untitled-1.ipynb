# %%
# %load_ext autoreload
# %autoreload 2

# %%
import meerkat as mk
import hapi
hapi.config.data_dir = '/data/hapi'
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /root/code/meerkat/meerkat/columns/Untitled-1.ipynb Cell 2' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://k8s-container%2Bcontext%3Dgke_hai-gcp-fine-grained_us-west1-a_cluster-1%2Bpodname%3Dsabri-pod-dev-gpu%2Bnamespace%3Ddefault%2Bname%3Dpod-dev-gpu%2Bimage%3Dgcr.io%252fhai-gcp-fine-grained%252fdev-node/root/code/meerkat/meerkat/columns/Untitled-1.ipynb#ch0000001vscode-remote?line=0'>1</a> import meerkat as mk
#       <a href='vscode-notebook-cell://k8s-container%2Bcontext%3Dgke_hai-gcp-fine-grained_us-west1-a_cluster-1%2Bpodname%3Dsabri-pod-dev-gpu%2Bnamespace%3Ddefault%2Bname%3Dpod-dev-gpu%2Bimage%3Dgcr.io%252fhai-gcp-fine-grained%252fdev-node/root/code/meerkat/meerkat/columns/Untitled-1.ipynb#ch0000001vscode-remote?line=1'>2</a> import hapi
# ...

# %%
dp = hapi.get_dataset("mir")

# %%
obj = hapi.get_labels(dataset="mir")
obj.keys()
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# dict_keys(['mic/mir'])

# %%
labels["true_label"]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /home/common/miniconda3/envs/mocha/lib/python3.10/site-packages/IPython/core/formatters.py:343, in BaseFormatter.__call__(self, obj)
#     341     method = get_real_method(obj, self.print_method)
#     342     if method is not None:
# --> 343         return method()
#     344     return None
#     345 else:
#
# File /home/sabri/code/meerkat/meerkat/columns/abstract.py:275, in AbstractColumn._repr_html_(self, max_rows)
#     272     pd_index = np.arange(len(self))
#     274 col_name = f"({self.__class__.__name__})"
# --> 275 col, formatter = self._repr_pandas_(max_rows=max_rows)
#     276 df = col.to_frame(name=col_name)
#     277 df = df.set_index(pd_index.astype(int))
#
# File /home/sabri/code/meerkat/meerkat/columns/abstract.py:256, in AbstractColumn._repr_pandas_(self, max_rows)
#     253 else:
# ...

# %%
labels = mk.DataPanel(hapi.get_labels(dataset="mir")["mic/mir"])
dp.merge(labels, on="example_id")
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /home/common/miniconda3/envs/mocha/lib/python3.10/site-packages/IPython/core/formatters.py:343, in BaseFormatter.__call__(self, obj)
#     341     method = get_real_method(obj, self.print_method)
#     342     if method is not None:
# --> 343         return method()
#     344     return None
#     345 else:
#
# File /home/sabri/code/meerkat/meerkat/datapanel.py:104, in DataPanel._repr_html_(self, max_rows)
#     101 if max_rows is None:
#     102     max_rows = meerkat.config.display.max_rows
# --> 104 df, formatters = self._repr_pandas_(max_rows=max_rows)
#     106 return df.to_html(formatters=formatters, max_rows=max_rows, escape=False)
#
# File /home/sabri/code/meerkat/meerkat/datapanel.py:93, in DataPanel._repr_pandas_(self, max_rows)
#      90 if max_rows is None:
# ...

# %%
out = hapi.get_predictions(task="mic")
# Out:
#   0%|          | 0/18 [00:00<?, ?it/s]

# %%
labels = hapi.get_labels(task="mic")
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
dp = mk.get("mirflickr")

# %%
dp
# Out:
# DataPanel(nrows: 25000, ncols: 27)

# %%
labels["mic/mir"]
# Out:
# [{'example_id': 'im20100',
#   'true_label': ['plant_life', 'sky', 'structures', 'tree']},
#  {'example_id': 'im9115',
#   'true_label': ['indoor', 'male', 'people', 'structures']},
#  {'example_id': 'im24473',
#   'true_label': ['animals', 'clouds', 'plant_life', 'sky']},
#  {'example_id': 'im17442',
#   'true_label': ['female', 'people', 'portrait', 'structures']},
#  {'example_id': 'im13141', 'true_label': ['indoor']},
#  {'example_id': 'im21974',
#   'true_label': ['clouds', 'lake', 'plant_life', 'sky', 'tree', 'water']},
#  {'example_id': 'im23711', 'true_label': ['food', 'indoor']},
#  {'example_id': 'im18005',
#   'true_label': ['female', 'indoor', 'people', 'portrait']},
#  {'example_id': 'im8278',
#   'true_label': ['plant_life', 'sky', 'structures', 'tree']},
#  {'example_id': 'im1280',
#   'true_label': ['female',
#    'flower',
#    'indoor',
#    'male',
#    'people',
#    'plant_life',
#    'portrait',
#    'structures']},
# ...

# %%
hapi.summary()["task"].unique()
# Out:
# array(['scr', 'fer', 'ner', 'str', 'sa', 'mic'], dtype=object)

# %%
hapi.get_predic
# Out:
#     task  dataset                 api      date  \
# 0    scr  command          google_scr  20-03-29
# 1    scr  command             ibm_scr  20-03-29
# 2    scr  command  deepspeech_lib_scr  20-03-29
# 3    scr  command       microsoft_scr  20-03-29
# 4    scr  command             ibm_scr  22-05-23
# ..   ...      ...                 ...       ...
# 171  fer  ferplus          facepp_fer  22-05-23
# 172  fer  ferplus          google_fer  22-05-23
# 173   sa     imdb            baidu_sa  21-02-21
# 174   sa     imdb           amazon_sa  21-02-21
# 175   sa     imdb           google_sa  21-02-21
#
#                                              path  cost_per_10k
# 0            scr/command/google_scr/20-03-29.json         60.00
# 1               scr/command/ibm_scr/20-03-29.json         25.00
# 2    scr/command/deepspeech_lib_scr/20-03-29.json          0.02
# 3         scr/command/microsoft_scr/20-03-29.json         41.00
# ...
