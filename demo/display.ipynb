# %%
"""Demo script."""
import meerkat as mk

mk.gui.start(api_port=5003, frontend_port=8010, dev=False)
# Out:
# (APIInfo(api=<fastapi.applications.FastAPI object at 0x7f9598ad5040>, port=5003, server=<meerkat.interactive.server.Server object at 0x7f95a8571730>, name='127.0.0.1', shared=False, process=None, _url=None),
#  FrontendInfo(package_manager='npm', port=8010, name='localhost', shared=False, process=<Popen: returncode: None args: ['python', '-m', 'http.server', '8010']>, _url=None))

# %%
# Load the dataframe
df = mk.get("imagenette", version="160px")

# %%
df.gui.gallery()
# Out:
#         <iframe
#             width="100%"
#             height="1000px"
#             src="http://localhost:8010/?id=gallery"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
