# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import meerkat as mk
import numpy as np
from meerkat.ops.embed import embed
from meerkat.ops.match import match

# %%
dp = mk.get("imagenette", dataset_dir="/Users/arjundesai/.cache/meerkat/datasets")
dp = dp[100:300]
# Fake clip embeddings
# dp["clip(img)"] = np.random.rand(*(len(dp), 512))

# %%
out = match(data=dp, query="car", input="img")
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
out.head()
# Out:
# DataPanel(nrows: 5, ncols: 15)

# %%
mk.sort(out, by="_match_img_car", ascending=False)
# Out:
# DataPanel(nrows: 200, ncols: 15)
