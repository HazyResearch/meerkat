# %%
# %load_ext autoreload
# %autoreload 2

# %%
# setup
import pathlib
base_dir = pathlib.Path("/Users/eyubogln/.meerkat/datasets/rfw/")

# %% [markdown]
# # Auditing Machine Learning Models with Meerkat
#
#
# In this demo, we’ll be using the Racial Faces in the Wild (RFW) dataset to audit AWS’s FaceCompare API. We provide predictions from the API on this dataset. Your task is to analyze model performance on this dataset and identify slices where the model is performing particularly poorly or particularly well.
#
# In order to audit the API, we’ll be using a tool we’re developing that helps data scientists help wrangle and analyze unstructured data: it’s called [Meerkat](https://meerkat.readthedocs.io/en/latest/guide/guide.html). Under the hood, it uses techniques like those described in [Domino](https://meerkat.readthedocs.io/en/latest/guide/guide.html) to identifying underperforming populations in machine learning datasets.
#
# So, let’s import the Python package and get started!

# %%
import meerkat as mk

# %% [markdown]
# ## Loading Data
#
# Meerkat provides a [registry](https://meerkat.readthedocs.io/en/dev/datasets/datasets.html) of commonly used datasets, like RFW, which allows us to load the data into memory with one line of code.  We can then merge the dataset with a CSV containing the model predictions.
#
# In memory, the dataset and model predictions are stored in a [Meerkat DataPanel](https://meerkat.readthedocs.io/en/latest/guide/data_structures.html). A `DataPanel` is in many ways just like a Pandas DataFrame: it’s a tabular data structure made up of columns. Unlike a DataFrame though, the `DataPanel` is designed for unstructured data types like images and audio. As you can see in the table visualization below, there’s a column for the image, the false non-match rate (FNMR), id etc.

# %%
dp = mk.get("rfw")
dp.head(3)
# Out:
# DataPanel(nrows: 3, ncols: 4)

# %% [markdown]
# **Loading CompareFaces Errors**. CompareFaces is an operation in Amazon Rekognition that predicts whether two images are taken of the same person. We've applied CompareFaces v6 (an AWS service) to the RFW dataset and stored the error rates for each image in the file `facecompare_v6_errors.csv`. Specifically, we've computed the *False Non-Match Rate* (FNMR) for each image, a measure of how often the model falsely predicts that two images are **not** of the same person.
#
# <div>
# <img src="fnmr.png" width="400"/>
# </div>
#
# We can load these error rates into our DataPanel with a single `DataPanel.merge` call which is equivalent to a `merge` in Pandas or a `join` in SQL. After doing this, we can see that the FNMR for each image is stored in the new `v6_fnmr` column.

# %%
dp = dp.merge(
	mk.DataPanel.from_csv(base_dir / "themis/facecompare_v6_errors.csv"),
	on="image_id",
)
dp.head(3)
# Out:
# DataPanel(nrows: 3, ncols: 5)

# %% [markdown]
# There are a number of operations that can be performed on a `DataPanel`, for example, we can use `sample` to randomly shuffle the dataset.

# %%
dp = dp.sample(frac=1, replace=False)

# %% [markdown]
# ## Exploring the Dataset
#
# To help with explore datasets with unstructured data types (*e.g.* images), Meerkat allows you to spin up interactive GUIs from within your notebook. These visualizations allow you to efficiently explore large image, audio, and video datasets.
#
# Note that the visualizations are highly customizable. There are a few different interface types (*e.g.  “*gallery”, “table”, “plot”) that can be customized from within the notebook.  See the documentation for a full list of interfaces.
#
# First though, we'll have to execute the two cells below to launch the interactive mode.

# %%
network, register_api = mk.interactive_mode()
# Out:
# > src@0.0.1 dev
# > vite dev "--port" "7862"
#
# 2:39:26 PM [vite] page reload .svelte-kit/runtime/app/env.js
# 2:39:26 PM [vite] page reload .svelte-kit/runtime/client/singletons.js
# 2:39:26 PM [vite] page reload .svelte-kit/runtime/client/start.js
# Port 7862 is in use, trying another one...
#
#   VITE v3.0.3  ready in 392 ms
#
#   ➜  Local:   http://localhost:7863/
#   ➜  Network: use --host to expose
# 2:39:27 PM [vite] hmr update /.svelte-kit/runtime/components/error.svelte
# 2:39:27 PM [vite] page reload .svelte-kit/runtime/env.js
# 2:39:27 PM [vite] page reload .svelte-kit/runtime/paths.js
# 2:39:27 PM [vite] page reload .svelte-kit/runtime/client/start.js
# 2:39:27 PM [vite] page reload .svelte-kit/generated/client-manifest.js
# 2:39:27 PM [vite] page reload .svelte-kit/generated/client-matchers.js
# 2:39:27 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:211:1 Unused CSS selector ".dragger"
# 2:39:27 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:226:0 Unused CSS selector ".dragger:hover"
# {
#   BASE_URL: '/',
#   MODE: 'development',
#   DEV: true,
#   PROD: false,
#   SSR: true
# }
# {
#   BASE_URL: '/',
#   MODE: 'development',
#   DEV: true,
#   PROD: false,
#   SSR: true
# }
# 2:39:27 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:211:1 Unused CSS selector ".dragger"
# 2:39:27 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:226:0 Unused CSS selector ".dragger:hover"
# 2:44:50 PM [vite] page reload .svelte-kit/runtime/app/env.js
# 2:44:50 PM [vite] page reload .svelte-kit/runtime/client/singletons.js
# 2:44:50 PM [vite] page reload .svelte-kit/runtime/client/start.js
# 2:44:50 PM [vite] page reload .svelte-kit/runtime/env.js
# 2:44:50 PM [vite] page reload .svelte-kit/runtime/paths.js
# 2:44:50 PM [vite] page reload .svelte-kit/generated/client-manifest.js
# 2:44:50 PM [vite] page reload .svelte-kit/generated/client-matchers.js
# 2:45:53 PM [vite] page reload .svelte-kit/runtime/app/env.js
# 2:45:53 PM [vite] page reload .svelte-kit/runtime/client/singletons.js
# 2:45:53 PM [vite] page reload .svelte-kit/runtime/client/start.js
# 2:45:53 PM [vite] page reload .svelte-kit/runtime/env.js
# 2:45:53 PM [vite] page reload .svelte-kit/runtime/paths.js
# 2:45:53 PM [vite] page reload .svelte-kit/generated/client-manifest.js
# 2:45:53 PM [vite] page reload .svelte-kit/generated/client-matchers.js
# 2:46:03 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:211:1 Unused CSS selector ".dragger"
# 2:46:03 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:226:0 Unused CSS selector ".dragger:hover"
# {
#   VITE_API_URL: 'testtest',
#   BASE_URL: '/',
#   MODE: 'development',
#   DEV: true,
#   PROD: false,
#   SSR: true
# }
# {
#   VITE_API_URL: 'testtest',
#   BASE_URL: '/',
#   MODE: 'development',
#   DEV: true,
#   PROD: false,
#   SSR: true
# }
# 2:46:04 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:211:1 Unused CSS selector ".dragger"
# 2:46:04 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:226:0 Unused CSS selector ".dragger:hover"
# 2:46:04 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/gallery/Gallery.svelte:146:1 Unused CSS selector ".dark .panel"
# 2:46:05 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/common/Slider.svelte:6:11 Slider has unused export property 'size'. If it is for external reference only, please consider using `export const size`
# 2:46:05 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/gallery/Card.svelte:104:1 Unused CSS selector ".card"
# 2:46:05 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/gallery/Card.svelte:114:1 Unused CSS selector ".dark .card"
# 2:46:05 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/gallery/Card.svelte:149:1 Unused CSS selector ".subcontent"
# 2:46:05 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/gallery/Card.svelte:171:1 Unused CSS selector ".subcontent:hover"
# 2:49:32 PM [vite] page reload .svelte-kit/runtime/app/env.js
# 2:49:32 PM [vite] page reload .svelte-kit/runtime/client/singletons.js
# 2:49:32 PM [vite] page reload .svelte-kit/runtime/client/start.js
# 2:49:32 PM [vite] page reload .svelte-kit/runtime/env.js
# 2:49:32 PM [vite] page reload .svelte-kit/runtime/paths.js
# 2:49:32 PM [vite] page reload .svelte-kit/generated/client-manifest.js
# 2:49:32 PM [vite] page reload .svelte-kit/generated/client-matchers.js
# 2:49:32 PM [vite] hmr update /src/routes/network/register.svelte
# hmr update /src/app.css
# hmr update /src/app.css
# hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# hmr update /src/lib/component/gallery/Gallery.svelte
# hmr update /src/app.css
# 2:49:32 PM [vite] page reload .svelte-kit/runtime/client/singletons.js
# 2:49:32 PM [vite] page reload .svelte-kit/runtime/client/start.js
# 2:49:32 PM [vite] hmr update /src/routes/network/register.svelte
# hmr update /src/app.css
# hmr update /src/app.css
# hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# hmr update /src/lib/component/gallery/Gallery.svelte
# hmr update /src/app.css
# 2:49:32 PM [vite] page reload .svelte-kit/runtime/paths.js
# 2:49:32 PM [vite] page reload .svelte-kit/generated/client-manifest.js
# 2:49:32 PM [vite] page reload .svelte-kit/generated/client-matchers.js
# 2:49:33 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:211:1 Unused CSS selector ".dragger"
# 2:49:33 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:226:0 Unused CSS selector ".dragger:hover"
# 2:49:33 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:211:1 Unused CSS selector ".dragger"
# 2:49:33 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:226:0 Unused CSS selector ".dragger:hover"
# 2:49:43 PM [vite] page reload .svelte-kit/runtime/app/env.js
# 2:49:43 PM [vite] page reload .svelte-kit/runtime/client/singletons.js
# 2:49:43 PM [vite] page reload .svelte-kit/runtime/client/start.js
# 2:49:43 PM [vite] hmr update /src/routes/network/register.svelte
# hmr update /src/routes/__layout.svelte
# hmr update /src/routes/__layout.svelte
# hmr update /src/routes/interface.svelte
# hmr update /src/routes/__layout.svelte
# hmr update /src/lib/component/gallery/Gallery.svelte
# hmr update /src/routes/__layout.svelte
# 2:49:43 PM [vite] page reload .svelte-kit/runtime/client/singletons.js
# 2:49:43 PM [vite] page reload .svelte-kit/runtime/client/start.js
# 2:49:43 PM [vite] hmr update /src/routes/network/register.svelte
# hmr update /src/routes/__layout.svelte
# hmr update /src/routes/__layout.svelte
# hmr update /src/routes/interface.svelte
# hmr update /src/routes/__layout.svelte
# hmr update /src/lib/component/gallery/Gallery.svelte
# hmr update /src/routes/__layout.svelte
# 2:49:43 PM [vite] page reload .svelte-kit/runtime/paths.js
# 2:49:43 PM [vite] page reload .svelte-kit/runtime/env.js
# 2:49:43 PM [vite] page reload .svelte-kit/runtime/paths.js
# 2:49:43 PM [vite] page reload .svelte-kit/generated/client-manifest.js
# 2:49:43 PM [vite] page reload .svelte-kit/generated/client-matchers.js
# 2:49:43 PM [vite] page reload .svelte-kit/generated/client-manifest.js
# 2:49:43 PM [vite] page reload .svelte-kit/generated/client-matchers.js
# 2:49:43 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:211:1 Unused CSS selector ".dragger"
# 2:49:43 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:226:0 Unused CSS selector ".dragger:hover"
# 2:52:19 PM [vite] hmr update /src/routes/interface.svelte
# hmr update /src/routes/__layout.svelte
# 2:52:19 PM [vite] hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# 2:52:21 PM [vite] hmr update /src/routes/interface.svelte
# hmr update /src/routes/__layout.svelte
# 2:52:21 PM [vite] hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# 2:52:30 PM [vite] hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# 2:52:30 PM [vite] hmr update /src/routes/interface.svelte
# hmr update /src/routes/__layout.svelte
# 2:52:30 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:210:1 Unused CSS selector ".dragger"
# 2:52:30 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:225:0 Unused CSS selector ".dragger:hover"
# 2:52:30 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:210:1 Unused CSS selector ".dragger"
# 2:52:30 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:225:0 Unused CSS selector ".dragger:hover"
# 2:52:42 PM [vite] page reload .svelte-kit/runtime/app/env.js
# 2:52:42 PM [vite] hmr update /src/routes/network/register.svelte
# hmr update /src/routes/__layout.svelte
# hmr update /src/routes/__layout.svelte
# hmr update /src/routes/interface.svelte
# hmr update /src/routes/__layout.svelte
# hmr update /src/lib/component/gallery/Gallery.svelte
# hmr update /src/routes/__layout.svelte
# 2:52:42 PM [vite] page reload .svelte-kit/runtime/client/singletons.js
# 2:52:42 PM [vite] page reload .svelte-kit/runtime/client/start.js
# 2:52:42 PM [vite] page reload .svelte-kit/runtime/client/singletons.js
# 2:52:42 PM [vite] page reload .svelte-kit/runtime/client/start.js
# 2:52:42 PM [vite] page reload .svelte-kit/runtime/env.js
# 2:52:42 PM [vite] page reload .svelte-kit/runtime/paths.js
# 2:52:42 PM [vite] hmr update /src/routes/network/register.svelte
# hmr update /src/routes/__layout.svelte
# hmr update /src/routes/__layout.svelte
# hmr update /src/routes/interface.svelte
# hmr update /src/routes/__layout.svelte
# hmr update /src/lib/component/gallery/Gallery.svelte
# hmr update /src/routes/__layout.svelte
# 2:52:42 PM [vite] page reload .svelte-kit/runtime/paths.js
# 2:52:42 PM [vite] page reload .svelte-kit/generated/client-manifest.js
# 2:52:42 PM [vite] page reload .svelte-kit/generated/client-matchers.js
# 2:52:42 PM [vite] page reload .svelte-kit/generated/client-manifest.js
# 2:52:42 PM [vite] page reload .svelte-kit/generated/client-matchers.js
# 2:52:46 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:210:1 Unused CSS selector ".dragger"
# 2:52:46 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:225:0 Unused CSS selector ".dragger:hover"
# api_url is not defined
# ReferenceError: api_url is not defined
#     at load (interface.svelte:5:38)
#     at load_node (file:///Users/eyubogln/code/meerkat/meerkat/interactive/app/.svelte-kit/runtime/server/index.js:2582:40)
#     at async respond$1 (file:///Users/eyubogln/code/meerkat/meerkat/interactive/app/.svelte-kit/runtime/server/index.js:2983:15)
#     at async resolve (file:///Users/eyubogln/code/meerkat/meerkat/interactive/app/.svelte-kit/runtime/server/index.js:3453:11)
#     at async respond (file:///Users/eyubogln/code/meerkat/meerkat/interactive/app/.svelte-kit/runtime/server/index.js:3389:20)
#     at async file:///Users/eyubogln/code/meerkat/meerkat/interactive/app/node_modules/@sveltejs/kit/dist/vite.js:1665:22
# api_url is not defined
# ReferenceError: api_url is not defined
#     at load (interface.svelte:5:38)
#     at load_node (file:///Users/eyubogln/code/meerkat/meerkat/interactive/app/.svelte-kit/runtime/server/index.js:2582:40)
#     at process.processTicksAndRejections (node:internal/process/task_queues:95:5)
#     at async respond$1 (file:///Users/eyubogln/code/meerkat/meerkat/interactive/app/.svelte-kit/runtime/server/index.js:2983:15)
#     at async resolve (file:///Users/eyubogln/code/meerkat/meerkat/interactive/app/.svelte-kit/runtime/server/index.js:3453:11)
#     at async respond (file:///Users/eyubogln/code/meerkat/meerkat/interactive/app/.svelte-kit/runtime/server/index.js:3389:20)
#     at async file:///Users/eyubogln/code/meerkat/meerkat/interactive/app/node_modules/@sveltejs/kit/dist/vite.js:1665:22
# 2:53:40 PM [vite] hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# 2:53:40 PM [vite] hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# 2:53:41 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:212:1 Unused CSS selector ".dragger"
# 2:53:41 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:227:0 Unused CSS selector ".dragger:hover"
# 2:54:21 PM [vite] page reload .svelte-kit/runtime/app/env.js
# 2:54:21 PM [vite] page reload .svelte-kit/runtime/client/singletons.js
# 2:54:21 PM [vite] hmr update /src/routes/network/register.svelte
# hmr update /src/routes/__layout.svelte
# hmr update /src/routes/__layout.svelte
# hmr update /src/lib/component/gallery/Gallery.svelte
# hmr update /src/routes/__layout.svelte
# 2:54:21 PM [vite] page reload .svelte-kit/runtime/client/start.js
# 2:54:21 PM [vite] page reload .svelte-kit/runtime/client/singletons.js
# 2:54:21 PM [vite] page reload .svelte-kit/runtime/client/start.js
# 2:54:21 PM [vite] hmr update /src/routes/network/register.svelte
# hmr update /src/routes/__layout.svelte
# hmr update /src/routes/__layout.svelte
# hmr update /src/lib/component/gallery/Gallery.svelte
# hmr update /src/routes/__layout.svelte
# 2:54:21 PM [vite] page reload .svelte-kit/runtime/paths.js
# 2:54:21 PM [vite] page reload .svelte-kit/runtime/env.js
# 2:54:21 PM [vite] page reload .svelte-kit/runtime/paths.js
# 2:54:21 PM [vite] page reload .svelte-kit/generated/client-manifest.js
# 2:54:21 PM [vite] page reload .svelte-kit/generated/client-matchers.js
# 2:54:21 PM [vite] page reload .svelte-kit/generated/client-manifest.js
# 2:54:21 PM [vite] page reload .svelte-kit/generated/client-matchers.js
# 2:54:22 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:212:1 Unused CSS selector ".dragger"
# 2:54:22 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:227:0 Unused CSS selector ".dragger:hover"
# 2:55:28 PM [vite] hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# 2:55:28 PM [vite] hmr update /src/routes/interface.svelte
# hmr update /src/routes/__layout.svelte
# 2:55:28 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:212:1 Unused CSS selector ".dragger"
# 2:55:28 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:227:0 Unused CSS selector ".dragger:hover"
# 2:55:40 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:212:1 Unused CSS selector ".dragger"
# 2:55:40 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:227:0 Unused CSS selector ".dragger:hover"
# 2:55:40 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:212:1 Unused CSS selector ".dragger"
# 2:55:40 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:227:0 Unused CSS selector ".dragger:hover"
# 2:55:43 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:212:1 Unused CSS selector ".dragger"
# 2:55:43 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:227:0 Unused CSS selector ".dragger:hover"
# 2:56:25 PM [vite] hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# 2:56:25 PM [vite] hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# 2:56:25 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:213:1 Unused CSS selector ".dragger"
# 2:56:25 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:228:0 Unused CSS selector ".dragger:hover"
# 2:56:30 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:213:1 Unused CSS selector ".dragger"
# 2:56:30 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:228:0 Unused CSS selector ".dragger:hover"
# 2:56:30 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:213:1 Unused CSS selector ".dragger"
# 2:56:30 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:228:0 Unused CSS selector ".dragger:hover"
# 2:56:41 PM [vite] hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# 2:56:41 PM [vite] hmr update /src/routes/interface.svelte
# hmr update /src/routes/__layout.svelte
# 2:56:41 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:215:1 Unused CSS selector ".dragger"
# 2:56:41 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:230:0 Unused CSS selector ".dragger:hover"
# 2:56:42 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:215:1 Unused CSS selector ".dragger"
# 2:56:42 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:230:0 Unused CSS selector ".dragger:hover"
# {
#   VITE_API_URL: 'testtest',
#   BASE_URL: '/',
#   MODE: 'development',
#   DEV: true,
#   PROD: false,
#   SSR: true
# }
# {
#   VITE_API_URL: 'testtest',
#   BASE_URL: '/',
#   MODE: 'development',
#   DEV: true,
#   PROD: false,
#   SSR: true
# }
# 2:56:43 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:215:1 Unused CSS selector ".dragger"
# 2:56:43 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:230:0 Unused CSS selector ".dragger:hover"
# 2:56:43 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:215:1 Unused CSS selector ".dragger"
# 2:56:43 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:230:0 Unused CSS selector ".dragger:hover"
# 2:56:45 PM [vite] hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# 2:56:45 PM [vite] hmr update /src/routes/interface.svelte
# hmr update /src/routes/__layout.svelte
# 2:56:45 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:214:1 Unused CSS selector ".dragger"
# 2:56:45 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:229:0 Unused CSS selector ".dragger:hover"
# 2:56:45 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:214:1 Unused CSS selector ".dragger"
# 2:56:45 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:229:0 Unused CSS selector ".dragger:hover"
# 2:56:45 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:214:1 Unused CSS selector ".dragger"
# 2:56:45 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:229:0 Unused CSS selector ".dragger:hover"
# {
#   VITE_API_URL: 'testtest',
#   BASE_URL: '/',
#   MODE: 'development',
#   DEV: true,
#   PROD: false,
#   SSR: true
# }
# {
#   VITE_API_URL: 'testtest',
#   BASE_URL: '/',
#   MODE: 'development',
#   DEV: true,
#   PROD: false,
#   SSR: true
# }
# 2:57:01 PM [vite] hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# 2:57:01 PM [vite] hmr update /src/routes/interface.svelte
# hmr update /src/routes/__layout.svelte
# 2:57:01 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:213:1 Unused CSS selector ".dragger"
# 2:57:01 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:228:0 Unused CSS selector ".dragger:hover"
# 2:57:41 PM [vite] hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# 2:57:41 PM [vite] hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# 2:57:41 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:212:1 Unused CSS selector ".dragger"
# 2:57:41 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:227:0 Unused CSS selector ".dragger:hover"
# {
#   VITE_API_URL: 'testtest',
#   BASE_URL: '/',
#   MODE: 'development',
#   DEV: true,
#   PROD: false,
#   SSR: true
# }
# {
#   VITE_API_URL: 'testtest',
#   BASE_URL: '/',
#   MODE: 'development',
#   DEV: true,
#   PROD: false,
#   SSR: true
# }
# /src/lib/utils/requests.ts:25
#     throw new Error(
#           ^
#
# Error: HTTP status 404: Not Found
#  url: http://127.0.0.1:7862/store/ac9846cf8d0342aaa766151bcfce84e5/trigger
#  data: {"value":[]}
#     at post (/src/lib/utils/requests.ts:25:11)
#     at process.processTicksAndRejections (node:internal/process/task_queues:95:5)
#     at async Module.modify (/src/lib/utils/requests.ts:34:23)
#     at async store_trigger (/src/routes/interface.svelte:164:23)
#
# Node.js v18.4.0
# 2:58:05 PM [vite] page reload .svelte-kit/runtime/app/env.js
# 2:58:05 PM [vite] page reload .svelte-kit/runtime/client/singletons.js
# 2:58:05 PM [vite] page reload .svelte-kit/runtime/client/start.js
# 2:58:05 PM [vite] page reload .svelte-kit/runtime/client/start.js
# 2:58:05 PM [vite] page reload .svelte-kit/runtime/env.js
# 2:58:05 PM [vite] page reload .svelte-kit/runtime/paths.js
# 2:58:05 PM [vite] page reload .svelte-kit/generated/client-manifest.js
# 2:58:05 PM [vite] page reload .svelte-kit/generated/client-matchers.js
# 2:58:39 PM [vite] hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# 2:58:56 PM [vite] hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# 2:59:11 PM [vite] hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# 2:59:12 PM [vite] hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# 2:59:12 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:213:1 Unused CSS selector ".dragger"
# 2:59:12 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:228:0 Unused CSS selector ".dragger:hover"
# 2:59:35 PM [vite] hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# 3:00:30 PM [vite] hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# 3:01:49 PM [vite] hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# 3:01:49 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:214:1 Unused CSS selector ".dragger"
# 3:01:49 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:229:0 Unused CSS selector ".dragger:hover"
# 3:01:57 PM [vite] hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# 3:02:11 PM [vite] page reload .svelte-kit/runtime/app/env.js
# 3:02:11 PM [vite] page reload .svelte-kit/runtime/client/singletons.js
# 3:02:11 PM [vite] page reload .svelte-kit/runtime/client/start.js
# 3:02:11 PM [vite] page reload .svelte-kit/runtime/client/start.js
# 3:02:11 PM [vite] page reload .svelte-kit/runtime/env.js
# 3:02:11 PM [vite] page reload .svelte-kit/runtime/paths.js
# 3:02:11 PM [vite] page reload .svelte-kit/generated/client-manifest.js
# 3:02:11 PM [vite] page reload .svelte-kit/generated/client-matchers.js
# 3:02:53 PM [vite] page reload .svelte-kit/runtime/app/env.js
# 3:02:53 PM [vite] page reload .svelte-kit/runtime/client/singletons.js
# 3:02:53 PM [vite] page reload .svelte-kit/runtime/client/start.js
# 3:02:53 PM [vite] page reload .svelte-kit/runtime/env.js
# 3:02:53 PM [vite] page reload .svelte-kit/runtime/paths.js
# 3:02:53 PM [vite] page reload .svelte-kit/generated/client-manifest.js
# 3:02:53 PM [vite] page reload .svelte-kit/generated/client-matchers.js
# 3:03:41 PM [vite] hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# 3:04:27 PM [vite] page reload .svelte-kit/runtime/app/env.js
# 3:04:27 PM [vite] page reload .svelte-kit/runtime/client/singletons.js
# 3:04:27 PM [vite] page reload .svelte-kit/runtime/client/start.js
# 3:04:27 PM [vite] page reload .svelte-kit/runtime/client/start.js
# 3:04:27 PM [vite] page reload .svelte-kit/runtime/env.js
# 3:04:27 PM [vite] page reload .svelte-kit/runtime/paths.js
# 3:04:27 PM [vite] page reload .svelte-kit/generated/client-manifest.js
# 3:04:27 PM [vite] page reload .svelte-kit/generated/client-matchers.js
# 3:05:30 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:211:1 Unused CSS selector ".dragger"
# 3:05:30 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:226:0 Unused CSS selector ".dragger:hover"
# 3:05:45 PM [vite] page reload .svelte-kit/runtime/app/env.js
# 3:05:45 PM [vite] page reload .svelte-kit/runtime/client/singletons.js
# 3:05:45 PM [vite] page reload .svelte-kit/runtime/client/start.js
# 3:05:45 PM [vite] page reload .svelte-kit/runtime/env.js
# 3:05:45 PM [vite] page reload .svelte-kit/runtime/paths.js
# 3:05:45 PM [vite] page reload .svelte-kit/generated/client-manifest.js
# 3:05:45 PM [vite] page reload .svelte-kit/generated/client-matchers.js
# 3:06:24 PM [vite] page reload .svelte-kit/runtime/app/env.js
# 3:06:24 PM [vite] page reload .svelte-kit/runtime/client/singletons.js
# 3:06:24 PM [vite] page reload .svelte-kit/runtime/client/start.js
# 3:06:24 PM [vite] page reload .svelte-kit/runtime/env.js
# 3:06:24 PM [vite] page reload .svelte-kit/runtime/paths.js
# 3:06:24 PM [vite] page reload .svelte-kit/generated/client-manifest.js
# 3:06:24 PM [vite] page reload .svelte-kit/generated/client-matchers.js
# 3:08:27 PM [vite] page reload .svelte-kit/runtime/app/env.js
# 3:08:27 PM [vite] page reload .svelte-kit/runtime/client/singletons.js
# 3:08:27 PM [vite] page reload .svelte-kit/runtime/client/start.js
# 3:08:27 PM [vite] page reload .svelte-kit/runtime/env.js
# 3:08:27 PM [vite] page reload .svelte-kit/runtime/paths.js
# 3:08:27 PM [vite] page reload .svelte-kit/generated/client-manifest.js
# 3:08:27 PM [vite] page reload .svelte-kit/generated/client-matchers.js
# 3:17:06 PM [vite] page reload .svelte-kit/runtime/app/env.js
# 3:17:06 PM [vite] page reload .svelte-kit/runtime/client/singletons.js
# 3:17:06 PM [vite] page reload .svelte-kit/runtime/client/start.js
# 3:17:07 PM [vite] page reload .svelte-kit/runtime/env.js
# 3:17:07 PM [vite] page reload .svelte-kit/runtime/paths.js
# 3:17:07 PM [vite] page reload .svelte-kit/generated/client-manifest.js
# 3:17:07 PM [vite] page reload .svelte-kit/generated/client-matchers.js
# 3:17:24 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:211:1 Unused CSS selector ".dragger"
# 3:17:24 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:226:0 Unused CSS selector ".dragger:hover"
# 3:18:14 PM [vite] page reload .svelte-kit/runtime/app/env.js
# 3:18:14 PM [vite] page reload .svelte-kit/runtime/client/singletons.js
# 3:18:14 PM [vite] page reload .svelte-kit/runtime/client/start.js
# 3:18:14 PM [vite] page reload .svelte-kit/runtime/env.js
# 3:18:14 PM [vite] page reload .svelte-kit/runtime/paths.js
# 3:18:14 PM [vite] page reload .svelte-kit/generated/client-manifest.js
# 3:18:14 PM [vite] page reload .svelte-kit/generated/client-matchers.js
# 3:18:14 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:211:1 Unused CSS selector ".dragger"
# 3:18:14 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:226:0 Unused CSS selector ".dragger:hover"
# 3:18:48 PM [vite] page reload .svelte-kit/runtime/app/env.js
# 3:18:48 PM [vite] page reload .svelte-kit/runtime/client/singletons.js
# 3:18:48 PM [vite] page reload .svelte-kit/runtime/client/start.js
# 3:18:48 PM [vite] page reload .svelte-kit/runtime/env.js
# 3:18:48 PM [vite] page reload .svelte-kit/runtime/paths.js
# 3:18:48 PM [vite] page reload .svelte-kit/generated/client-manifest.js
# 3:18:48 PM [vite] page reload .svelte-kit/generated/client-matchers.js
# 3:18:49 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:211:1 Unused CSS selector ".dragger"
# 3:18:49 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:226:0 Unused CSS selector ".dragger:hover"
# 3:20:12 PM [vite] page reload .svelte-kit/runtime/app/env.js
# 3:20:12 PM [vite] page reload .svelte-kit/runtime/client/singletons.js
# 3:20:12 PM [vite] page reload .svelte-kit/runtime/client/start.js
# 3:20:12 PM [vite] page reload .svelte-kit/runtime/client/start.js
# 3:20:12 PM [vite] page reload .svelte-kit/runtime/env.js
# 3:20:12 PM [vite] page reload .svelte-kit/runtime/paths.js
# 3:20:12 PM [vite] page reload .svelte-kit/generated/client-manifest.js
# 3:20:12 PM [vite] page reload .svelte-kit/generated/client-matchers.js
# 3:20:12 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:211:1 Unused CSS selector ".dragger"
# 3:20:12 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:226:0 Unused CSS selector ".dragger:hover"
# 3:22:26 PM [vite] page reload .svelte-kit/runtime/app/env.js
# 3:22:26 PM [vite] page reload .svelte-kit/runtime/client/singletons.js
# 3:22:26 PM [vite] page reload .svelte-kit/runtime/client/start.js
# 3:22:26 PM [vite] page reload .svelte-kit/runtime/env.js
# 3:22:26 PM [vite] page reload .svelte-kit/runtime/paths.js
# 3:22:27 PM [vite] page reload .svelte-kit/generated/client-manifest.js
# 3:22:27 PM [vite] page reload .svelte-kit/generated/client-matchers.js
# 3:22:27 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:211:1 Unused CSS selector ".dragger"
# 3:22:27 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:226:0 Unused CSS selector ".dragger:hover"
# 3:37:08 PM [vite] page reload .svelte-kit/runtime/app/env.js
# 3:37:08 PM [vite] page reload .svelte-kit/runtime/client/singletons.js
# 3:37:08 PM [vite] page reload .svelte-kit/runtime/client/start.js
# 3:37:08 PM [vite] page reload .svelte-kit/runtime/client/start.js
# 3:37:08 PM [vite] page reload .svelte-kit/runtime/env.js
# 3:37:08 PM [vite] page reload .svelte-kit/runtime/paths.js
# 3:37:08 PM [vite] page reload .svelte-kit/generated/client-manifest.js
# 3:37:08 PM [vite] page reload .svelte-kit/generated/client-matchers.js
# 3:37:08 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:211:1 Unused CSS selector ".dragger"
# 3:37:08 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:226:0 Unused CSS selector ".dragger:hover"
# 3:37:55 PM [vite] page reload .svelte-kit/runtime/app/env.js
# 3:37:55 PM [vite] page reload .svelte-kit/runtime/client/singletons.js
# 3:37:55 PM [vite] page reload .svelte-kit/runtime/client/start.js
# 3:37:55 PM [vite] page reload .svelte-kit/runtime/env.js
# 3:37:55 PM [vite] page reload .svelte-kit/runtime/paths.js
# 3:37:55 PM [vite] page reload .svelte-kit/generated/client-manifest.js
# 3:37:55 PM [vite] page reload .svelte-kit/generated/client-matchers.js
# 3:37:56 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:211:1 Unused CSS selector ".dragger"
# 3:37:56 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:226:0 Unused CSS selector ".dragger:hover"
# 3:43:51 PM [vite] page reload .svelte-kit/runtime/app/env.js
# 3:43:51 PM [vite] page reload .svelte-kit/runtime/client/singletons.js
# 3:43:51 PM [vite] page reload .svelte-kit/runtime/client/start.js
# 3:43:51 PM [vite] page reload .svelte-kit/runtime/client/start.js
# 3:43:51 PM [vite] page reload .svelte-kit/runtime/env.js
# 3:43:51 PM [vite] page reload .svelte-kit/runtime/paths.js
# 3:43:51 PM [vite] page reload .svelte-kit/generated/client-manifest.js
# 3:43:51 PM [vite] page reload .svelte-kit/generated/client-matchers.js
# 3:43:52 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:211:1 Unused CSS selector ".dragger"
# 3:43:52 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:226:0 Unused CSS selector ".dragger:hover"
# 3:49:02 PM [vite] page reload .svelte-kit/runtime/app/env.js
# 3:49:02 PM [vite] page reload .svelte-kit/runtime/client/singletons.js
# 3:49:02 PM [vite] page reload .svelte-kit/runtime/client/start.js
# 3:49:03 PM [vite] page reload .svelte-kit/runtime/client/start.js
# 3:49:03 PM [vite] page reload .svelte-kit/runtime/env.js
# 3:49:03 PM [vite] page reload .svelte-kit/runtime/paths.js
# 3:49:03 PM [vite] page reload .svelte-kit/generated/client-manifest.js
# 3:49:03 PM [vite] page reload .svelte-kit/generated/client-matchers.js
# 3:49:04 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:211:1 Unused CSS selector ".dragger"
# 3:49:04 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:226:0 Unused CSS selector ".dragger:hover"

# %%
register_api()
# Out:
#         <iframe
#             width="1"
#             height="1"
#             src="http://localhost:7862/network/register?api=http://127.0.0.1:7861"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# To begin, understanding the errors, we'll sort the DataPanel by the FNMR column and then launch a new interface.

# %%
dp = dp.sort(by="v6_fnmr", ascending=False) 
dp.gui.table(id_column="image_id")
# Out:
#         <iframe
#             width="100%"
#             height="1000"
#             src="http://localhost:7862/interface?id=e3011c3e867c4a4193dac4fdfb5d9306"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# Triggering store 2f64c7d114174b12964f521601ee50b5 image_id
# Triggering store ea63cb64574d4013a7d432e35ad48ee4 image_id
# Browser:  false
# SSR
# Browser:  false
# SSR
# Triggering store 2f64c7d114174b12964f521601ee50b5 image_id
# Triggering store ea63cb64574d4013a7d432e35ad48ee4 image_id
# 2:32:50 PM [vite] hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# 2:32:50 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:212:1 Unused CSS selector ".dragger"
# 2:32:50 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:227:0 Unused CSS selector ".dragger:hover"
# 2:33:12 PM [vite] hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# 2:33:13 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:194:1 'MODE' is not defined
# 2:33:13 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:212:1 Unused CSS selector ".dragger"
# 2:33:13 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:227:0 Unused CSS selector ".dragger:hover"
# 2:36:58 PM [vite] hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# 2:36:58 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:212:1 Unused CSS selector ".dragger"
# 2:36:58 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:227:0 Unused CSS selector ".dragger:hover"
# 2:36:58 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:212:1 Unused CSS selector ".dragger"
# 2:36:58 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:227:0 Unused CSS selector ".dragger:hover"
# The "path" argument must be of type string. Received undefined
# TypeError [ERR_INVALID_ARG_TYPE]: The "path" argument must be of type string. Received undefined
#     at new NodeError (node:internal/errors:388:5)
#     at validateString (node:internal/validators:114:11)
#     at Object.join (node:path:1172:7)
#     at lookupFile (/Users/eyubogln/code/meerkat/meerkat/interactive/app/node_modules/vite/dist/node-cjs/publicUtils.cjs:3435:40)
#     at Proxy.loadEnv (/Users/eyubogln/code/meerkat/meerkat/interactive/app/node_modules/vite/dist/node-cjs/publicUtils.cjs:4178:22)
#     at interface.svelte:34:13
#     at Object.$$render (/node_modules/svelte/internal/index.mjs:1770:22)
#     at Object.default (root.svelte:43:39)
#     at eval (/src/routes/__layout.svelte:13:41)
#     at Object.$$render (/node_modules/svelte/internal/index.mjs:1770:22)
# 2:36:59 PM [vite] ✨ new dependencies optimized: vite
# 2:36:59 PM [vite] ✨ optimized dependencies changed. reloading
# 2:36:59 PM [vite] warning:
# /Users/eyubogln/code/meerkat/meerkat/interactive/app/node_modules/.vite/deps/chunk-Y5QA3PMD.js
# 22836|  };
# 22837|  var importDefault = async (filepath) => {
# 22838|    const module2 = await import(url$4.pathToFileURL(filepath).href);
#    |                                 ^
# 22839|    return module2.default;
# 22840|  };
# The above dynamic import cannot be analyzed by vite.
# See https://github.com/rollup/plugins/tree/master/packages/dynamic-import-vars#limitations for supported dynamic import formats. If this is intended to be left as-is, you can use the /* @vite-ignore */ comment inside the import() call to suppress this warning.
#
#   Plugin: vite:import-analysis
#   File: /Users/eyubogln/code/meerkat/meerkat/interactive/app/node_modules/.vite/deps/chunk-Y5QA3PMD.js?v=152ef9c0
# 2:36:59 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:212:1 Unused CSS selector ".dragger"
# 2:36:59 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:227:0 Unused CSS selector ".dragger:hover"
# The "path" argument must be of type string. Received undefined
# TypeError [ERR_INVALID_ARG_TYPE]: The "path" argument must be of type string. Received undefined
#     at new NodeError (node:internal/errors:388:5)
#     at validateString (node:internal/validators:114:11)
#     at Object.join (node:path:1172:7)
#     at lookupFile (/Users/eyubogln/code/meerkat/meerkat/interactive/app/node_modules/vite/dist/node-cjs/publicUtils.cjs:3435:40)
#     at Proxy.loadEnv (/Users/eyubogln/code/meerkat/meerkat/interactive/app/node_modules/vite/dist/node-cjs/publicUtils.cjs:4178:22)
#     at interface.svelte:34:13
#     at Object.$$render (/node_modules/svelte/internal/index.mjs:1770:22)
#     at Object.default (root.svelte:43:39)
#     at eval (/src/routes/__layout.svelte:13:41)
#     at Object.$$render (/node_modules/svelte/internal/index.mjs:1770:22)
# 2:37:29 PM [vite] hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# 2:37:29 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:212:1 Unused CSS selector ".dragger"
# 2:37:29 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:227:0 Unused CSS selector ".dragger:hover"
# {
#   BASE_URL: '/',
#   MODE: 'development',
#   DEV: true,
#   PROD: false,
#   SSR: true
# }
# 2:37:29 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:212:1 Unused CSS selector ".dragger"
# 2:37:29 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:227:0 Unused CSS selector ".dragger:hover"
# 2:37:37 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:212:1 Unused CSS selector ".dragger"
# 2:37:37 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:227:0 Unused CSS selector ".dragger:hover"
# 2:38:12 PM [vite] hmr update /src/routes/interface.svelte
# hmr update /src/routes/__layout.svelte
# 2:38:12 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:212:1 Unused CSS selector ".dragger"
# 2:38:12 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:227:0 Unused CSS selector ".dragger:hover"
# /
# 2:38:12 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:212:1 Unused CSS selector ".dragger"
# 2:38:12 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:227:0 Unused CSS selector ".dragger:hover"
# 2:38:18 PM [vite] hmr update /src/routes/interface.svelte
# hmr update /src/routes/__layout.svelte
# 2:38:18 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:211:1 Unused CSS selector ".dragger"
# 2:38:18 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:226:0 Unused CSS selector ".dragger:hover"
# 2:38:18 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:211:1 Unused CSS selector ".dragger"
# 2:38:18 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:226:0 Unused CSS selector ".dragger:hover"
# /
# 2:38:18 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:211:1 Unused CSS selector ".dragger"
# 2:38:18 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:226:0 Unused CSS selector ".dragger:hover"
# 2:38:33 PM [vite] hmr update /src/routes/interface.svelte
# hmr update /src/routes/__layout.svelte
# 2:38:33 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:211:1 Unused CSS selector ".dragger"
# 2:38:33 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:226:0 Unused CSS selector ".dragger:hover"

# %% [markdown]
# ## Computing global metrics
# Next we’ll  compute some average metrics across the entire dataset to get a sense of how the model is performing globally.

# %%
global_fnmr = dp["v6_fnmr"].mean()
print(f"Global False Non-Match Rate: {global_fnmr: .2%}")
# Out:
# Global False Non-Match Rate:  2.28%

# %% [markdown]
# ## Computing group statistics
#
# RFW provides annotations for limited set of high-level racial groups. In ths section, we’ll see how performance varies when stratifying by these groups. To do so, we’ll use `mk.groupby`.

# %%
gb = dp.groupby("ethnicity")
gb["v6_fnmr"].mean()
# Out:
# DataPanel(nrows: 4, ncols: 2)

# %%
type(dp["v6_fnmr"][0].item() )
# Out:
# float

# %% [markdown]
# We can also visualize the groups in a `GroupBy` with the `cards` interface:

# %%
gb.gui.cards(
    main_column="image", 
    tag_columns=["v6_fnmr"],
    aggregations={
        "Mean FNMR": lambda x: x["v6_fnmr"].mean(),
        "STD FNMR": lambda x: x["v6_fnmr"].std(),
        "Size": len,
    }
)
# Out:
#         <iframe
#             width="100%"
#             height="1000"
#             src="http://localhost:7862/interface?id=c0d96631ed8a4dcaa208ba191a698e1c"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# Triggering store d24791cf83fe4fe78aa08c3d7fdfc581 image_id
# 10:49:46 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/component/slicebycards/RowCard.svelte:21:11 RowCard has unused export property 'layout'. If it is for external reference only, please consider using `export const layout`
# 10:49:46 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/component/slicebycards/RowCard.svelte:24:11 RowCard has unused export property 'card_flex_grow'. If it is for external reference only, please consider using `export const card_flex_grow`
# 10:49:46 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/component/slicebycards/RowCard.svelte:53:11 RowCard has unused export property 'main_modal'. If it is for external reference only, please consider using `export const main_modal`
# 10:49:47 AM [vite] ✨ new dependencies optimized: tippy.js

# %% [markdown]
# ## Going beyond available metadata...
#
# The trouble is, the subgroup annotations provided in RFW are quite limited. What if there are other groups that we'd like to explore for which we lack annotations?
#
# This is where things start to get interesting: we are goinng to use large, pretrained models in order to bootstrap our dataset with more metadata! This is the key idea behind Meerkat.
#
# To demonstrate this idea, we've implemented the `match` operation in the GUI. With `match`, we can create new columns by writing natural language queries and matching them to the images. For example, say we want a metadata column that tells us whether the person in the image is wearing sunglasses. We can write a query like: "A person wearing sunglasses."
#
# Let's try it out below. First, we'll need to `embed` the images into a latent space using a pretrained encoder (e.g. CLIP). Meerkat includes a registry of available encoders, so we can just specify one in the `mk.embed` call.

# %%
# In practice, columns can be embedded using `mk.embed`, however, for time's sake, we'll 
# just merge in the embeddings below
# dp = mk.embed(dp, input="image", num_workers=0, encoder="clip", device=0)

dp = dp.merge(
    mk.DataPanel.read(base_dir / "main/rfw_embedded.mk")["image_id", "clip(image)"],
    on="image_id"
)

# %%
dp.gui.table()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/eyubogln/code/meerkat/scratch/sabri/08-15-themis_demo.ipynb Cell 25' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/eyubogln/code/meerkat/scratch/sabri/08-15-themis_demo.ipynb#ch0000022?line=0'>1</a> dp.gui.table()
#
# File ~/code/meerkat/meerkat/interactive/gui.py:47, in DataPanelGUI.table(self, *args, **kwargs)
#      46 def table(self, *args, **kwargs) -> IFrame:
# ---> 47     interface = MatchTableInterface(dp=self.dp, *args, **kwargs)
#      48     return interface.launch()
#
# File ~/code/meerkat/meerkat/interactive/app/src/lib/interfaces/abstract.py:49, in InterfaceMeta.__call__(cls, *args, **kwargs)
#      48 def __call__(cls, *args, **kwargs):
# ---> 49     instance = super().__call__(*args, **kwargs)
#      50     # Automatically call the layout method when the
#      51     # interface is created
#      52     instance._layout()
#
# TypeError: __init__() missing 1 required positional argument: 'id_column'

# %% [markdown]
# Matching produces a continuous score for each image in the dataset. We'd like to find a *threshold score* above which people are wearing sunglasses. Using the gallery view we can find this threshold quite easily.

# %%
dp["sunglasses"] = dp["_match_image_A person wearing sunglasses."] - dp["_match_image_A person."]
dp = dp.sort(by="sunglasses", ascending=False)
dp.gui.table()
# Out:
#         <iframe
#             width="100%"
#             height="1000"
#             src="http://localhost:7861/interface?id=8649a46396bd4e35a886691e7fc4f672"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# In here.
# http://127.0.0.1:7860
# Response {
#   [Symbol(realm)]: null,
#   [Symbol(state)]: {
#     aborted: false,
#     rangeRequested: false,
#     timingAllowPassed: true,
#     requestIncludesCredentials: true,
#     type: 'default',
#     status: 200,
#     timingInfo: {
#       startTime: 40864.37191605568,
#       redirectStartTime: 40864.37191605568,
#       redirectEndTime: 40865.6775829792,
#       postRedirectStartTime: 40865.6775829792,
#       finalServiceWorkerStartTime: 0,
#       finalNetworkResponseStartTime: 0,
#       finalNetworkRequestStartTime: 0,
#       endTime: 0,
#       encodedBodySize: 0,
#       decodedBodySize: 0,
#       finalConnectionTimingInfo: null
#     },
#     cacheState: '',
#     statusText: 'OK',
#     headersList: HeadersList {
#       [Symbol(headers map)]: [Map],
#       [Symbol(headers map sorted)]: null
#     },
#     urlList: [ [URL], [URL] ],
#     body: { stream: undefined }
#   },
#   [Symbol(headers)]: HeadersList {
#     [Symbol(headers map)]: Map(4) {
#       'date' => 'Thu, 18 Aug 2022 21:23:33 GMT',
#       'server' => 'uvicorn',
#       'content-length' => '100',
#       'content-type' => 'application/json'
#     },
#     [Symbol(headers map sorted)]: null
#   }
# }
# {
#   component: 'table',
#   props: {
#     type: 'table',
#     nrows: 40528,
#     dp: '72887d51ed3b4be7900273382bc31159'
#   }
# }
# http://127.0.0.1:7860/dp/72887d51ed3b4be7900273382bc31159/rows
# start: 0
# end: 100
# indices: undefined
# columns: undefined

# %%
dp["sunglasses"] = dp["sunglasses"] > -0.23
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/eyubogln/code/meerkat/scratch/sabri/08-15-themis_demo.ipynb Cell 28' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/eyubogln/code/meerkat/scratch/sabri/08-15-themis_demo.ipynb#ch0000025?line=0'>1</a> dp["sunglasses"] = dp["sunglasses"] > -0.23
#
# File ~/code/meerkat/meerkat/datapanel.py:311, in DataPanel.__getitem__(self, index)
#     310 def __getitem__(self, index):
# --> 311     return self._get(index, materialize=True)
#
# File ~/code/meerkat/meerkat/datapanel.py:249, in DataPanel._get(self, index, materialize)
#     247     if index in self.columns:
#     248         return self.data[index]
# --> 249     raise KeyError(f"Column `{index}` does not exist.")
#     251 elif isinstance(index, int):
#     252     # int index => single row (dict)
#     253     return {
#     254         k: self.data[k]._get(index, materialize=materialize)
#     255         for k in self.columns
#     256     }
#
# KeyError: 'Column `sunglasses` does not exist.'

# %%
dp = dp.sample(frac=1, replace=False)

# %%
gb = dp.groupby(by="sunglasses")
gb["v6_fnmr"].mean()
# Out:
# DataPanel(nrows: 2, ncols: 2)

# %%
gb.gui.cards(
    main_column="image", 
    tag_columns=["v6_fnmr"],
    aggregations={
        "Mean FNMR": lambda x: x["v6_fnmr"].mean(),
        "STD FNMR": lambda x: x["v6_fnmr"].std(),
        "Size": len,
    }
)
# Out:
#         <iframe
#             width="100%"
#             height="1000"
#             src="http://localhost:7861/interface?id=dabbedf56d2d4427b5539d7a079ceb62"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# In here.
# http://127.0.0.1:7860
# Response {
#   [Symbol(realm)]: null,
#   [Symbol(state)]: {
#     aborted: false,
#     rangeRequested: false,
#     timingAllowPassed: true,
#     requestIncludesCredentials: true,
#     type: 'default',
#     status: 200,
#     timingInfo: {
#       startTime: 125846.68587505817,
#       redirectStartTime: 125846.68587505817,
#       redirectEndTime: 125848.81166601181,
#       postRedirectStartTime: 125848.81166601181,
#       finalServiceWorkerStartTime: 0,
#       finalNetworkResponseStartTime: 0,
#       finalNetworkRequestStartTime: 0,
#       endTime: 0,
#       encodedBodySize: 0,
#       decodedBodySize: 0,
#       finalConnectionTimingInfo: null
#     },
#     cacheState: '',
#     statusText: 'OK',
#     headersList: HeadersList {
#       [Symbol(headers map)]: [Map],
#       [Symbol(headers map sorted)]: null
#     },
#     urlList: [ [URL], [URL] ],
#     body: { stream: undefined }
#   },
#   [Symbol(headers)]: HeadersList {
#     [Symbol(headers map)]: Map(4) {
#       'date' => 'Thu, 18 Aug 2022 21:24:57 GMT',
#       'server' => 'uvicorn',
#       'content-length' => '360',
#       'content-type' => 'application/json'
#     },
#     [Symbol(headers map sorted)]: null
#   }
# }
# {
#   component: 'sliceby-cards',
#   props: {
#     type: 'sliceby-cards',
#     sliceby_id: '5c4ad375833e40ca88725de53794aa32',
#     datapanel_id: 'dd0b1b55141342c58a2b388a5f1e81c3',
#     main_column: 'image',
#     tag_columns: [ 'v6_fnmr' ],
#     aggregations: {
#       'Mean FNMR': '3cd52087756f476788171a60eaa70832',
#       'STD FNMR': '861f1e9db0734f3d93918bcce4ab8cda',
#       Size: '605fb741cd5b4cf8ae9af0513f28b648'
#     }
#   }
# }
# Mean FNMR
# 3cd52087756f476788171a60eaa70832
# STD FNMR
# 861f1e9db0734f3d93918bcce4ab8cda
# Size
# 605fb741cd5b4cf8ae9af0513f28b648
# {
#   'Mean FNMR': { dp: { false: ' 0.022541', true: ' 0.038014' } },
#   'STD FNMR': { dp: { false: ' 0.109713', true: ' 0.14555' } },
#   Size: { dp: { false: ' 39677', true: ' 851' } }
# }

# %%
dp.gui.table()

# %% [markdown]
# ## Discovering slices
#
# The subgroup annotations provided in RFW are quite limited, so we’ll use meerkat to *discover* new slices. To do so, we’ll use `dp.explainby`, a method that identifies a set of slices (*i.e.* scalar functions of the `by` column) that explain the variance in the response variable.

# %%
from meerkat.ops.sliceby.explainby import explainby

# dp = mk.DataPanel.read(base_dir / "themis/facecompare_v6_global_slices.mk")

indian_dp = dp.lz[dp["ethnicity"] == "indian"] 

eb = explainby(indian_dp, by="image", target="v6_fnmr",  n_slices=10, use_cache=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/eyubogln/code/meerkat/scratch/sabri/08-15-themis_demo.ipynb Cell 31' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/eyubogln/code/meerkat/scratch/sabri/08-15-themis_demo.ipynb#ch0000028?line=0'>1</a> from meerkat.ops.sliceby.explainby import explainby
#       <a href='vscode-notebook-cell:/Users/eyubogln/code/meerkat/scratch/sabri/08-15-themis_demo.ipynb#ch0000028?line=2'>3</a> # dp = mk.DataPanel.read(base_dir / "themis/facecompare_v6_global_slices.mk")
#       <a href='vscode-notebook-cell:/Users/eyubogln/code/meerkat/scratch/sabri/08-15-themis_demo.ipynb#ch0000028?line=4'>5</a> indian_dp = dp.lz[dp["ethnicity"] == "indian"]
#
# ModuleNotFoundError: No module named 'meerkat.ops.sliceby.explainby'

# %%
eb.gui.cards(
    main_column="image", 
    tag_columns=["v6_fnmr", "ethnicity"],
    aggregations={
        "Mean FNMR": lambda x: x["v6_fnmr"].mean(),
        "STD FNMR": lambda x: x["v6_fnmr"].std(),
        "Size": len,
    }
)
# Out:
#         <iframe
#             width="100%"
#             height="1000"
#             src="http://localhost:7861/interface?id=c5cb91dd39af44b39fe8588b0bdc8bb1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# In here.
# http://127.0.0.1:7860
# Response {
#   [Symbol(realm)]: null,
#   [Symbol(state)]: {
#     aborted: false,
#     rangeRequested: false,
#     timingAllowPassed: true,
#     requestIncludesCredentials: true,
#     type: 'default',
#     status: 200,
#     timingInfo: {
#       startTime: 182679.6961660385,
#       redirectStartTime: 182679.6961660385,
#       redirectEndTime: 182681.21908307076,
#       postRedirectStartTime: 182681.21908307076,
#       finalServiceWorkerStartTime: 0,
#       finalNetworkResponseStartTime: 0,
#       finalNetworkRequestStartTime: 0,
#       endTime: 0,
#       encodedBodySize: 0,
#       decodedBodySize: 0,
#       finalConnectionTimingInfo: null
#     },
#     cacheState: '',
#     statusText: 'OK',
#     headersList: HeadersList {
#       [Symbol(headers map)]: [Map],
#       [Symbol(headers map sorted)]: null
#     },
#     urlList: [ [URL], [URL] ],
#     body: { stream: undefined }
#   },
#   [Symbol(headers)]: HeadersList {
#     [Symbol(headers map)]: Map(4) {
#       'date' => 'Thu, 18 Aug 2022 21:25:54 GMT',
#       'server' => 'uvicorn',
#       'content-length' => '372',
#       'content-type' => 'application/json'
#     },
#     [Symbol(headers map sorted)]: null
#   }
# }
# {
#   component: 'sliceby-cards',
#   props: {
#     type: 'sliceby-cards',
#     sliceby_id: 'd0576819fa9e4706b9c35f320b621324',
#     datapanel_id: '297c7baaf17f400d82ea0090475989d4',
#     main_column: 'image',
#     tag_columns: [ 'v6_fnmr', 'ethnicity' ],
#     aggregations: {
#       'Mean FNMR': '96a86835506f45569bcf434724c1882d',
#       'STD FNMR': 'd123a6b0bcfb4ae49da427a61f5f9c99',
#       Size: 'fca8f39f3ea543079a8ca65cfaf49967'
#     }
#   }
# }
# Mean FNMR
# 96a86835506f45569bcf434724c1882d
# STD FNMR
# d123a6b0bcfb4ae49da427a61f5f9c99
# Size
# fca8f39f3ea543079a8ca65cfaf49967
# {
#   'Mean FNMR': {
#     dp: {
#       '0': ' 0.071018',
#       '1': ' 0.059524',
#       '2': ' 0.058559',
#       '3': ' 0.047126',
#       '4': ' 0.047401',
#       '5': ' 0.044223',
#       '6': ' 0.042954',
#       '7': ' 0.035335',
#       '8': ' 0.03347',
#       '9': ' 0.032338'
#     }
#   },
#   'STD FNMR': {
#     dp: {
#       '0': ' 0.201545',
#       '1': ' 0.157297',
#       '2': ' 0.199757',
#       '3': ' 0.187066',
#       '4': ' 0.178142',
#       '5': ' 0.155331',
#       '6': ' 0.161938',
#       '7': ' 0.147754',
#       '8': ' 0.133669',
#       '9': ' 0.124406'
#     }
#   },
#   Size: {
#     dp: {
#       '0': ' 203',
#       '1': ' 231',
#       '2': ' 74',
#       '3': ' 145',
#       '4': ' 109',
#       '5': ' 251',
#       '6': ' 1223',
#       '7': ' 383',
#       '8': ' 122',
#       '9': ' 201'
#     }
#   }
# }

# %%
dp = mk.get("imagenette")
# Out:
# 10:53:14 AM [vite] page reload src/lib/api/llm.ts
# 10:53:14 AM [vite] hmr update /src/lib/component/StoreComponent.svelte
# hmr update /src/app.css
# 10:53:14 AM [vite] hmr update /src/app.css
# hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# hmr update /src/routes/interface.svelte?svelte&type=style&lang.css
# 10:53:14 AM [vite] hmr update /src/app.css
# hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# hmr update /src/routes/interface.svelte?svelte&type=style&lang.css
# 10:53:14 AM [vite] hmr update /src/lib/component/match/Match.svelte
# hmr update /src/app.css
# hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# hmr update /src/routes/interface.svelte?svelte&type=style&lang.css
# 10:53:14 AM [vite] hmr update /src/app.css
# hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# hmr update /src/routes/interface.svelte?svelte&type=style&lang.css
# 10:53:14 AM [vite] hmr update /src/lib/component/slicebycards/RowCard.svelte
# hmr update /src/app.css
# hmr update /src/lib/component/slicebycards/RowCard.svelte?svelte&type=style&lang.css
# hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# hmr update /src/routes/interface.svelte?svelte&type=style&lang.css
# 10:53:14 AM [vite] hmr update /src/lib/component/slicebycards/SliceByCard.svelte
# hmr update /src/app.css
# hmr update /src/lib/component/slicebycards/SliceByCard.svelte?svelte&type=style&lang.css
# hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# hmr update /src/routes/interface.svelte?svelte&type=style&lang.css
# 10:53:14 AM [vite] hmr update /src/lib/component/slicebycards/SliceByCards.svelte
# hmr update /src/app.css
# hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# hmr update /src/routes/interface.svelte?svelte&type=style&lang.css
# 10:53:14 AM [vite] hmr update /src/lib/component/table/Table.svelte
# hmr update /src/app.css
# hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# hmr update /src/routes/interface.svelte?svelte&type=style&lang.css
# 10:53:14 AM [vite] page reload src/lib/components/abstract/Block.svelte
# 10:53:14 AM [vite] page reload src/lib/components/abstract/BlockGroup.svelte
# 10:53:14 AM [vite] page reload src/lib/components/abstract/Interface.svelte
# 10:53:14 AM [vite] page reload src/lib/components/abstract/Operator.svelte
# 10:53:14 AM [vite] page reload src/lib/components/abstract/View.svelte
# 10:53:14 AM [vite] page reload src/lib/components/abstract/stores.js
# 10:53:14 AM [vite] hmr update /src/app.css
# hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# hmr update /src/lib/component/StoreComponent.svelte
# hmr update /src/app.css
# hmr update /src/app.css
# hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# hmr update /src/app.css
# hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# hmr update /src/lib/component/match/Match.svelte
# hmr update /src/app.css
# 10:53:14 AM [vite] page reload src/lib/components/blocks/Block.svelte
# 10:53:14 AM [vite] page reload src/lib/components/blocks/Dummy.svelte
# 10:53:14 AM [vite] page reload src/lib/components/blocks/DummyBlock.svelte
# 10:53:14 AM [vite] page reload src/lib/components/blocks/DummyPlot.svelte
# 10:53:14 AM [vite] page reload src/lib/components/blocks/DummyTable.svelte
# 10:53:14 AM [vite] page reload src/lib/components/blocks/Everything.svelte
# 10:53:14 AM [vite] page reload src/lib/components/blocks/Filter.svelte
# 10:53:14 AM [vite] page reload src/lib/components/blocks/Gallery.svelte
# 10:53:14 AM [vite] page reload src/lib/components/blocks/NewBlock.svelte
# 10:53:14 AM [vite] page reload src/lib/components/blocks/stores.js
# 10:53:14 AM [vite] hmr update /src/lib/components/cell/basic/Basic.svelte
# hmr update /src/app.css
# 10:53:14 AM [vite] page reload src/lib/components/layout.svelte
# 10:53:14 AM [vite] page reload src/lib/components/lm/CategoryGenerator.svelte
# 10:53:14 AM [vite] page reload src/lib/components/lm/Node.svelte
# 10:53:14 AM [vite] page reload src/lib/components/lm/SchemaTree.svelte
# 10:53:14 AM [vite] page reload src/lib/utils/graph.ts
# 10:53:14 AM [vite] page reload src/routes/old_interface.svelte
# 10:53:14 AM [vite] page reload src/routes/tests/blocks/TestDummy.svelte
# 10:53:14 AM [vite] page reload src/lib/TableView.svelte
# 10:53:14 AM [vite] hmr update /src/app.css
# hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# hmr update /src/lib/component/match/Match.svelte
# hmr update /src/app.css
# 10:53:14 AM [vite] page reload src/lib/api/sliceby.ts
# 10:53:14 AM [vite] hmr update /src/lib/components/cell/Cell.svelte
# hmr update /src/app.css
# 10:53:14 AM [vite] hmr update /src/lib/components/common/Pill.svelte
# hmr update /src/app.css
# 10:53:14 AM [vite] page reload src/lib/components/gallery/Card.svelte
# 10:53:14 AM [vite] page reload src/lib/components/gallery/Gallery.svelte
# 10:53:14 AM [vite] hmr update /src/app.css
# hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# hmr update /src/app.css
# hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# hmr update /src/lib/component/match/Match.svelte
# hmr update /src/app.css
# 10:53:14 AM [vite] page reload src/routes/index.svelte
# 10:53:14 AM [vite] hmr update /src/routes/interface.svelte?svelte&type=style&lang.css
# hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# 10:53:14 AM [vite] page reload .svelte-kit/generated/client-manifest.js
# 10:53:15 AM [vite] hmr update /src/lib/components/table/Table.svelte
# hmr update /src/routes/__layout.svelte
# hmr update /src/lib/components/table/Table.svelte
# hmr update /src/routes/__layout.svelte
# 10:53:16 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/TableView.svelte:164:1 Unused CSS selector ".dark .table-view"
# 10:53:16 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/TableView.svelte:164:1 Unused CSS selector ".dark .table-view"
# 10:53:16 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/sliceby/SliceCard.svelte:9:11 SliceCard has unused export property 'datapanel_id'. If it is for external reference only, please consider using `export const datapanel_id`
# 10:53:16 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/plot_header/PlotHeader.svelte:8:11 PlotHeader has unused export property 'rows_promise'. If it is for external reference only, please consider using `export const rows_promise`
# 10:53:16 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/sliceby/SliceCard.svelte:9:11 SliceCard has unused export property 'datapanel_id'. If it is for external reference only, please consider using `export const datapanel_id`
# 10:53:16 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/plot_header/PlotHeader.svelte:8:11 PlotHeader has unused export property 'rows_promise'. If it is for external reference only, please consider using `export const rows_promise`
# 10:53:17 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/match_header/MatchHeader.svelte:104:1 Unused CSS selector ".list-container"
# 10:53:17 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/filter_header/FilterHeader.svelte:133:1 Unused CSS selector ".list-container"
# 10:53:17 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/gallery/Gallery.svelte:112:1 Unused CSS selector ".dark .panel"
# 10:53:17 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/table/Table.svelte:102:1 Unused CSS selector ".dark .table"
# 10:53:17 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/match_header/MatchHeader.svelte:104:1 Unused CSS selector ".list-container"
# 10:53:17 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/table/Table.svelte:102:1 Unused CSS selector ".dark .table"
# 10:53:17 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/filter_header/FilterHeader.svelte:133:1 Unused CSS selector ".list-container"
# 10:53:17 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/gallery/Gallery.svelte:112:1 Unused CSS selector ".dark .panel"
# 10:53:17 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/row/RowCard.svelte:21:11 RowCard has unused export property 'layout'. If it is for external reference only, please consider using `export const layout`
# 10:53:17 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/row/RowCard.svelte:24:11 RowCard has unused export property 'card_flex_grow'. If it is for external reference only, please consider using `export const card_flex_grow`
# 10:53:17 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/row/RowCard.svelte:53:11 RowCard has unused export property 'main_modal'. If it is for external reference only, please consider using `export const main_modal`
# 10:53:17 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/common/Toggle.svelte:31:0 Unused CSS selector ".dark .label"
# 10:53:17 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/common/Toggle.svelte:74:1 Unused CSS selector ".dark .toggle"
# 10:53:17 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/row/RowCard.svelte:21:11 RowCard has unused export property 'layout'. If it is for external reference only, please consider using `export const layout`
# 10:53:17 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/row/RowCard.svelte:24:11 RowCard has unused export property 'card_flex_grow'. If it is for external reference only, please consider using `export const card_flex_grow`
# 10:53:17 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/row/RowCard.svelte:53:11 RowCard has unused export property 'main_modal'. If it is for external reference only, please consider using `export const main_modal`
# 10:53:17 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/common/Slider.svelte:6:11 Slider has unused export property 'size'. If it is for external reference only, please consider using `export const size`
# 10:53:17 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/common/Slider.svelte:6:11 Slider has unused export property 'size'. If it is for external reference only, please consider using `export const size`
# 10:53:17 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/common/Toggle.svelte:31:0 Unused CSS selector ".dark .label"
# 10:53:17 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/common/Toggle.svelte:74:1 Unused CSS selector ".dark .toggle"
# 10:53:18 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/gallery/Card.svelte:101:1 Unused CSS selector ".card"
# 10:53:18 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/gallery/Card.svelte:111:1 Unused CSS selector ".dark .card"
# 10:53:18 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/gallery/Card.svelte:146:1 Unused CSS selector ".subcontent"
# 10:53:18 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/gallery/Card.svelte:168:1 Unused CSS selector ".subcontent:hover"
# 10:53:18 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/gallery/Card.svelte:101:1 Unused CSS selector ".card"
# 10:53:18 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/gallery/Card.svelte:111:1 Unused CSS selector ".dark .card"
# 10:53:18 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/gallery/Card.svelte:146:1 Unused CSS selector ".subcontent"
# 10:53:18 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/gallery/Card.svelte:168:1 Unused CSS selector ".subcontent:hover"
# 10:53:18 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/table/Table.svelte:102:1 Unused CSS selector ".dark .table"
# 10:53:19 AM [vite] ✨ new dependencies optimized: d3-brush, d3-selection, d3-quadtree
# 10:53:19 AM [vite] ✨ optimized dependencies changed. reloading
# 10:53:20 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/common/Toggle.svelte:31:0 Unused CSS selector ".dark .label"
# 10:53:20 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/common/Toggle.svelte:74:1 Unused CSS selector ".dark .toggle"
# 10:53:20 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/sliceby/SliceCard.svelte:9:11 SliceCard has unused export property 'datapanel_id'. If it is for external reference only, please consider using `export const datapanel_id`
# 10:53:20 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/row/RowCard.svelte:21:11 RowCard has unused export property 'layout'. If it is for external reference only, please consider using `export const layout`
# 10:53:20 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/row/RowCard.svelte:24:11 RowCard has unused export property 'card_flex_grow'. If it is for external reference only, please consider using `export const card_flex_grow`
# 10:53:20 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/row/RowCard.svelte:53:11 RowCard has unused export property 'main_modal'. If it is for external reference only, please consider using `export const main_modal`
# In here.
# In here.
# In here.
# In here.
# In here.
# In here.
#
# Response {
#   [Symbol(realm)]: null,
#   [Symbol(state)]: {
#     aborted: false,
#     rangeRequested: false,
#     timingAllowPassed: true,
#     requestIncludesCredentials: true,
#     type: 'default',
#     status: 404,
#     timingInfo: {
#       startTime: 233950.87804102898,
#       redirectStartTime: 0,
#       redirectEndTime: 0,
#       postRedirectStartTime: 233950.87804102898,
#       finalServiceWorkerStartTime: 0,
#       finalNetworkResponseStartTime: 0,
#       finalNetworkRequestStartTime: 0,
#       endTime: 0,
#       encodedBodySize: 65317,
#       decodedBodySize: 65317,
#       finalConnectionTimingInfo: null
#     },
#     cacheState: '',
#     statusText: 'Not Found',
#     headersList: HeadersList {
#       [Symbol(headers map)]: [Map],
#       [Symbol(headers map sorted)]: null
#     },
#     urlList: [ [URL] ],
#     body: { stream: undefined }
#   },
#   [Symbol(headers)]: HeadersList {
#     [Symbol(headers map)]: Map(7) {
#       'access-control-allow-origin' => '*',
#       'content-type' => 'text/html',
#       'etag' => '"1y3gqpq"',
#       'date' => 'Thu, 01 Sep 2022 17:53:20 GMT',
#       'connection' => 'keep-alive',
#       'keep-alive' => 'timeout=5',
#       'transfer-encoding' => 'chunked'
#     },
#     [Symbol(headers map sorted)]: null
#   }
# }
#
# Response {
#   [Symbol(realm)]: null,
#   [Symbol(state)]: {
#     aborted: false,
#     rangeRequested: false,
#     timingAllowPassed: true,
#     requestIncludesCredentials: true,
#     type: 'default',
#     status: 404,
#     timingInfo: {
#       startTime: 233951.5502500534,
#       redirectStartTime: 0,
#       redirectEndTime: 0,
#       postRedirectStartTime: 233951.5502500534,
#       finalServiceWorkerStartTime: 0,
#       finalNetworkResponseStartTime: 0,
#       finalNetworkRequestStartTime: 0,
#       endTime: 0,
#       encodedBodySize: 65317,
#       decodedBodySize: 65317,
#       finalConnectionTimingInfo: null
#     },
#     cacheState: '',
#     statusText: 'Not Found',
#     headersList: HeadersList {
#       [Symbol(headers map)]: [Map],
#       [Symbol(headers map sorted)]: null
#     },
#     urlList: [ [URL] ],
#     body: { stream: undefined }
#   },
#   [Symbol(headers)]: HeadersList {
#     [Symbol(headers map)]: Map(7) {
#       'access-control-allow-origin' => '*',
#       'content-type' => 'text/html',
#       'etag' => '"1o4xfum"',
#       'date' => 'Thu, 01 Sep 2022 17:53:20 GMT',
#       'connection' => 'keep-alive',
#       'keep-alive' => 'timeout=5',
#       'transfer-encoding' => 'chunked'
#     },
#     [Symbol(headers map sorted)]: null
#   }
# }
#
# Response {
#   [Symbol(realm)]: null,
#   [Symbol(state)]: {
#     aborted: false,
#     rangeRequested: false,
#     timingAllowPassed: true,
#     requestIncludesCredentials: true,
#     type: 'default',
#     status: 404,
#     timingInfo: {
#       startTime: 233951.82783293724,
#       redirectStartTime: 0,
#       redirectEndTime: 0,
#       postRedirectStartTime: 233951.82783293724,
#       finalServiceWorkerStartTime: 0,
#       finalNetworkResponseStartTime: 0,
#       finalNetworkRequestStartTime: 0,
#       endTime: 0,
#       encodedBodySize: 65317,
#       decodedBodySize: 65317,
#       finalConnectionTimingInfo: null
#     },
#     cacheState: '',
#     statusText: 'Not Found',
#     headersList: HeadersList {
#       [Symbol(headers map)]: [Map],
#       [Symbol(headers map sorted)]: null
#     },
#     urlList: [ [URL] ],
#     body: { stream: undefined }
#   },
#   [Symbol(headers)]: HeadersList {
#     [Symbol(headers map)]: Map(7) {
#       'access-control-allow-origin' => '*',
#       'content-type' => 'text/html',
#       'etag' => '"1y3gqpq"',
#       'date' => 'Thu, 01 Sep 2022 17:53:20 GMT',
#       'connection' => 'keep-alive',
#       'keep-alive' => 'timeout=5',
#       'transfer-encoding' => 'chunked'
#     },
#     [Symbol(headers map sorted)]: null
#   }
# }
#
# Response {
#   [Symbol(realm)]: null,
#   [Symbol(state)]: {
#     aborted: false,
#     rangeRequested: false,
#     timingAllowPassed: true,
#     requestIncludesCredentials: true,
#     type: 'default',
#     status: 404,
#     timingInfo: {
#       startTime: 233952.06383299828,
#       redirectStartTime: 0,
#       redirectEndTime: 0,
#       postRedirectStartTime: 233952.06383299828,
#       finalServiceWorkerStartTime: 0,
#       finalNetworkResponseStartTime: 0,
#       finalNetworkRequestStartTime: 0,
#       endTime: 0,
#       encodedBodySize: 65317,
#       decodedBodySize: 65317,
#       finalConnectionTimingInfo: null
#     },
#     cacheState: '',
#     statusText: 'Not Found',
#     headersList: HeadersList {
#       [Symbol(headers map)]: [Map],
#       [Symbol(headers map sorted)]: null
#     },
#     urlList: [ [URL] ],
#     body: { stream: undefined }
#   },
#   [Symbol(headers)]: HeadersList {
#     [Symbol(headers map)]: Map(7) {
#       'access-control-allow-origin' => '*',
#       'content-type' => 'text/html',
#       'etag' => '"1o4xfum"',
#       'date' => 'Thu, 01 Sep 2022 17:53:20 GMT',
#       'connection' => 'keep-alive',
#       'keep-alive' => 'timeout=5',
#       'transfer-encoding' => 'chunked'
#     },
#     [Symbol(headers map sorted)]: null
#   }
# }
#
# Response {
#   [Symbol(realm)]: null,
#   [Symbol(state)]: {
#     aborted: false,
#     rangeRequested: false,
#     timingAllowPassed: true,
#     requestIncludesCredentials: true,
#     type: 'default',
#     status: 404,
#     timingInfo: {
#       startTime: 233952.42916584015,
#       redirectStartTime: 0,
#       redirectEndTime: 0,
#       postRedirectStartTime: 233952.42916584015,
#       finalServiceWorkerStartTime: 0,
#       finalNetworkResponseStartTime: 0,
#       finalNetworkRequestStartTime: 0,
#       endTime: 0,
#       encodedBodySize: 65317,
#       decodedBodySize: 65317,
#       finalConnectionTimingInfo: null
#     },
#     cacheState: '',
#     statusText: 'Not Found',
#     headersList: HeadersList {
#       [Symbol(headers map)]: [Map],
#       [Symbol(headers map sorted)]: null
#     },
#     urlList: [ [URL] ],
#     body: { stream: undefined }
#   },
#   [Symbol(headers)]: HeadersList {
#     [Symbol(headers map)]: Map(7) {
#       'access-control-allow-origin' => '*',
#       'content-type' => 'text/html',
#       'etag' => '"1y3gqpq"',
#       'date' => 'Thu, 01 Sep 2022 17:53:20 GMT',
#       'connection' => 'keep-alive',
#       'keep-alive' => 'timeout=5',
#       'transfer-encoding' => 'chunked'
#     },
#     [Symbol(headers map sorted)]: null
#   }
# }
#
# Response {
#   [Symbol(realm)]: null,
#   [Symbol(state)]: {
#     aborted: false,
#     rangeRequested: false,
#     timingAllowPassed: true,
#     requestIncludesCredentials: true,
#     type: 'default',
#     status: 404,
#     timingInfo: {
#       startTime: 233952.67795801163,
#       redirectStartTime: 0,
#       redirectEndTime: 0,
#       postRedirectStartTime: 233952.67795801163,
#       finalServiceWorkerStartTime: 0,
#       finalNetworkResponseStartTime: 0,
#       finalNetworkRequestStartTime: 0,
#       endTime: 0,
#       encodedBodySize: 65317,
#       decodedBodySize: 65317,
#       finalConnectionTimingInfo: null
#     },
#     cacheState: '',
#     statusText: 'Not Found',
#     headersList: HeadersList {
#       [Symbol(headers map)]: [Map],
#       [Symbol(headers map sorted)]: null
#     },
#     urlList: [ [URL] ],
#     body: { stream: undefined }
#   },
#   [Symbol(headers)]: HeadersList {
#     [Symbol(headers map)]: Map(7) {
#       'access-control-allow-origin' => '*',
#       'content-type' => 'text/html',
#       'etag' => '"1o4xfum"',
#       'date' => 'Thu, 01 Sep 2022 17:53:20 GMT',
#       'connection' => 'keep-alive',
#       'keep-alive' => 'timeout=5',
#       'transfer-encoding' => 'chunked'
#     },
#     [Symbol(headers map sorted)]: null
#   }
# }
# 10:53:24 AM [vite] page reload src/lib/components/abstract/Operator.svelte
# 10:53:24 AM [vite] page reload src/lib/components/abstract/View.svelte
# 10:53:24 AM [vite] hmr update /src/lib/components/row/RowCard.svelte
# hmr update /src/app.css
# hmr update /src/lib/components/row/RowCard.svelte
# hmr update /src/app.css
# 10:53:24 AM [vite] hmr update /src/lib/components/sliceby/SliceCard.svelte
# hmr update /src/app.css
# hmr update /src/lib/components/sliceby/SliceCard.svelte
# hmr update /src/app.css
# 10:53:24 AM [vite] hmr update /src/lib/components/sliceby/SliceCards.svelte
# hmr update /src/app.css
# 10:53:24 AM [vite] hmr update /src/app.css
# hmr update /src/lib/component/match/Match.svelte
# hmr update /src/lib/components/sliceby/SliceCards.svelte
# hmr update /src/app.css
# hmr update /src/lib/TableView.svelte
# hmr update /src/app.css
# hmr update /src/lib/components/plot_header/PlotHeader.svelte
# hmr update /src/app.css
# hmr update /src/lib/components/match_header/MatchHeader.svelte
# hmr update /src/app.css
# hmr update /src/lib/components/column_select/ColumnSelect.svelte
# hmr update /src/app.css
# 10:53:24 AM [vite] hmr update /src/app.css
# hmr update /src/lib/components/sliceby/SliceCards.svelte
# hmr update /src/app.css
# hmr update /src/lib/components/sliceby/SliceCard.svelte
# hmr update /src/app.css
# 10:53:24 AM [vite] page reload src/lib/api/llm.ts
# 10:53:24 AM [vite] hmr update /src/lib/component/StoreComponent.svelte
# 10:53:24 AM [vite] page reload src/lib/component/filter/Filter.svelte
# 10:53:24 AM [vite] page reload src/lib/component/filter/Filter.svelte
# 10:53:24 AM [vite] page reload src/lib/component/gallery/Gallery.svelte
# 10:53:24 AM [vite] page reload src/lib/component/gallery/Gallery.svelte
# 10:53:24 AM [vite] hmr update /src/lib/component/match/Match.svelte
# hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# hmr update /src/routes/interface.svelte?svelte&type=style&lang.css
# 10:53:24 AM [vite] hmr update /src/lib/component/match/Match.svelte
# 10:53:24 AM [vite] page reload src/lib/component/plot/Plot.svelte
# 10:53:24 AM [vite] page reload src/lib/component/plot/Plot.svelte
# 10:53:24 AM [vite] hmr update /src/lib/component/slicebycards/RowCard.svelte
# hmr update /src/lib/component/slicebycards/RowCard.svelte?svelte&type=style&lang.css
# hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# hmr update /src/routes/interface.svelte?svelte&type=style&lang.css
# 10:53:24 AM [vite] hmr update /src/lib/component/slicebycards/RowCard.svelte
# hmr update /src/lib/component/slicebycards/RowCard.svelte?svelte&type=style&lang.css
# 10:53:24 AM [vite] hmr update /src/lib/component/slicebycards/SliceByCard.svelte
# hmr update /src/lib/component/slicebycards/SliceByCard.svelte?svelte&type=style&lang.css
# hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# hmr update /src/routes/interface.svelte?svelte&type=style&lang.css
# 10:53:24 AM [vite] hmr update /src/lib/component/slicebycards/SliceByCard.svelte
# hmr update /src/lib/component/slicebycards/SliceByCard.svelte?svelte&type=style&lang.css
# 10:53:24 AM [vite] hmr update /src/lib/component/slicebycards/SliceByCards.svelte
# hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# hmr update /src/routes/interface.svelte?svelte&type=style&lang.css
# 10:53:24 AM [vite] hmr update /src/lib/component/slicebycards/SliceByCards.svelte
# 10:53:24 AM [vite] hmr update /src/lib/component/table/Table.svelte
# hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# hmr update /src/routes/interface.svelte?svelte&type=style&lang.css
# 10:53:24 AM [vite] hmr update /src/lib/component/table/Table.svelte
# 10:53:24 AM [vite] page reload src/lib/components/abstract/Block.svelte
# 10:53:24 AM [vite] page reload src/lib/components/abstract/BlockGroup.svelte
# 10:53:24 AM [vite] page reload src/lib/components/abstract/Interface.svelte
# 10:53:24 AM [vite] page reload src/lib/components/abstract/stores.js
# 10:53:24 AM [vite] hmr update /src/lib/component/StoreComponent.svelte
# hmr update /src/app.css
# hmr update /src/app.css
# hmr update /src/lib/component/match/Match.svelte
# hmr update /src/lib/components/sliceby/SliceCards.svelte
# hmr update /src/app.css
# hmr update /src/lib/TableView.svelte
# hmr update /src/app.css
# hmr update /src/lib/components/plot_header/PlotHeader.svelte
# hmr update /src/app.css
# hmr update /src/lib/components/match_header/MatchHeader.svelte
# hmr update /src/app.css
# hmr update /src/lib/components/column_select/ColumnSelect.svelte
# hmr update /src/app.css
# hmr update /src/lib/components/sliceby/SliceCards.svelte
# hmr update /src/app.css
# hmr update /src/app.css
# hmr update /src/lib/components/sliceby/SliceCards.svelte
# hmr update /src/app.css
# hmr update /src/lib/components/sliceby/SliceCard.svelte
# hmr update /src/app.css
# 10:53:24 AM [vite] page reload src/lib/components/blocks/Block.svelte
# 10:53:24 AM [vite] page reload src/lib/components/blocks/Dummy.svelte
# 10:53:24 AM [vite] page reload src/lib/components/blocks/DummyBlock.svelte
# 10:53:24 AM [vite] page reload src/lib/components/blocks/DummyPlot.svelte
# 10:53:24 AM [vite] page reload src/lib/components/blocks/DummyTable.svelte
# 10:53:24 AM [vite] page reload src/lib/components/blocks/Everything.svelte
# 10:53:24 AM [vite] page reload src/lib/components/blocks/Filter.svelte
# 10:53:24 AM [vite] page reload src/lib/components/blocks/Gallery.svelte
# 10:53:24 AM [vite] page reload src/lib/components/blocks/NewBlock.svelte
# 10:53:24 AM [vite] page reload src/lib/components/blocks/stores.js
# 10:53:24 AM [vite] hmr update /src/lib/components/cell/Cell.svelte
# hmr update /src/app.css
# 10:53:24 AM [vite] hmr update /src/lib/components/cell/basic/Basic.svelte
# 10:53:24 AM [vite] hmr update /src/lib/components/common/Pill.svelte
# hmr update /src/app.css
# 10:53:24 AM [vite] page reload src/lib/components/layout.svelte
# 10:53:24 AM [vite] page reload src/lib/components/lm/CategoryGenerator.svelte
# 10:53:24 AM [vite] page reload src/lib/components/lm/Node.svelte
# 10:53:24 AM [vite] page reload src/lib/components/lm/SchemaTree.svelte
# 10:53:24 AM [vite] page reload src/lib/utils/graph.ts
# 10:53:24 AM [vite] hmr update /src/app.css
# hmr update /src/app.css
# hmr update /src/lib/component/match/Match.svelte
# hmr update /src/lib/components/sliceby/SliceCards.svelte
# hmr update /src/app.css
# hmr update /src/lib/TableView.svelte
# hmr update /src/app.css
# hmr update /src/lib/components/plot_header/PlotHeader.svelte
# hmr update /src/app.css
# hmr update /src/lib/components/match_header/MatchHeader.svelte
# hmr update /src/app.css
# hmr update /src/lib/components/column_select/ColumnSelect.svelte
# hmr update /src/app.css
# hmr update /src/lib/components/sliceby/SliceCards.svelte
# hmr update /src/app.css
# hmr update /src/app.css
# hmr update /src/lib/components/sliceby/SliceCards.svelte
# hmr update /src/app.css
# hmr update /src/lib/components/sliceby/SliceCard.svelte
# hmr update /src/app.css
# 10:53:24 AM [vite] page reload src/routes/index.svelte
# 10:53:24 AM [vite] page reload src/routes/old_interface.svelte
# 10:53:24 AM [vite] page reload src/routes/tests/blocks/TestDummy.svelte
# 10:53:24 AM [vite] page reload .svelte-kit/generated/client-manifest.js
# 10:53:25 AM [vite] hmr update /src/lib/components/table/Table.svelte?svelte&type=style&lang.css
# hmr update /src/lib/components/table/Table.svelte
# hmr update /src/routes/__layout.svelte
# 10:53:25 AM [vite] hmr update /src/lib/components/gallery/Gallery.svelte?svelte&type=style&lang.css
# hmr update /src/lib/components/gallery/Gallery.svelte
# hmr update /src/routes/__layout.svelte
# 10:53:25 AM [vite] hmr update /src/lib/TableView.svelte
# hmr update /src/routes/__layout.svelte
# 10:53:25 AM [vite] hmr update /src/routes/interface.svelte?svelte&type=style&lang.css
# hmr update /src/routes/interface.svelte
# hmr update /src/routes/__layout.svelte
# 10:53:25 AM [vite] hmr update /src/lib/components/gallery/Card.svelte
# hmr update /src/routes/__layout.svelte
# 10:53:25 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:213:1 Unused CSS selector ".dragger"
# 10:53:25 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:228:0 Unused CSS selector ".dragger:hover"
# Triggering store d24791cf83fe4fe78aa08c3d7fdfc581 image_id
# Triggering store d24791cf83fe4fe78aa08c3d7fdfc581 image_id
# Triggering store d24791cf83fe4fe78aa08c3d7fdfc581 image_id
# Triggering store d24791cf83fe4fe78aa08c3d7fdfc581 image_id
# Triggering store d24791cf83fe4fe78aa08c3d7fdfc581 image_id
# Triggering store d24791cf83fe4fe78aa08c3d7fdfc581 image_id
# Triggering store d24791cf83fe4fe78aa08c3d7fdfc581 image_id
# Triggering store d24791cf83fe4fe78aa08c3d7fdfc581 image_id
# Triggering store d24791cf83fe4fe78aa08c3d7fdfc581 image_id
# Triggering store d24791cf83fe4fe78aa08c3d7fdfc581 image_id
# Triggering store d24791cf83fe4fe78aa08c3d7fdfc581 image_id
# Triggering store d24791cf83fe4fe78aa08c3d7fdfc581 image_id
# Triggering store d24791cf83fe4fe78aa08c3d7fdfc581 image_id
# Triggering store d24791cf83fe4fe78aa08c3d7fdfc581 image_id
# Triggering store d24791cf83fe4fe78aa08c3d7fdfc581 image_id
# Triggering store d24791cf83fe4fe78aa08c3d7fdfc581 image_id
# 10:53:26 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:213:1 Unused CSS selector ".dragger"
# 10:53:26 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:228:0 Unused CSS selector ".dragger:hover"
# 10:53:27 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/component/slicebycards/RowCard.svelte:21:11 RowCard has unused export property 'layout'. If it is for external reference only, please consider using `export const layout`
# 10:53:27 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/component/slicebycards/RowCard.svelte:24:11 RowCard has unused export property 'card_flex_grow'. If it is for external reference only, please consider using `export const card_flex_grow`
# 10:53:27 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/component/slicebycards/RowCard.svelte:53:11 RowCard has unused export property 'main_modal'. If it is for external reference only, please consider using `export const main_modal`
# 10:53:29 AM [vite] page reload src/routes/index.svelte
# Triggering store d24791cf83fe4fe78aa08c3d7fdfc581 image_id
# Triggering store d24791cf83fe4fe78aa08c3d7fdfc581 image_id
# 10:53:29 AM [vite] hmr update /src/routes/__layout.svelte
# hmr update /src/routes/__layout.svelte
# hmr update /src/lib/component/match/Match.svelte
# hmr update /src/routes/__layout.svelte
# hmr update /src/lib/components/sliceby/SliceCards.svelte
# hmr update /src/lib/TableView.svelte
# hmr update /src/routes/__layout.svelte
# hmr update /src/lib/components/plot_header/PlotHeader.svelte
# hmr update /src/routes/__layout.svelte
# hmr update /src/lib/components/match_header/MatchHeader.svelte
# hmr update /src/routes/__layout.svelte
# hmr update /src/lib/components/column_select/ColumnSelect.svelte
# hmr update /src/routes/__layout.svelte
# hmr update /src/routes/interface.svelte
# hmr update /src/routes/__layout.svelte
# hmr update /src/lib/components/sliceby/SliceCards.svelte
# hmr update /src/routes/__layout.svelte
# hmr update /src/lib/components/sliceby/SliceCards.svelte
# hmr update /src/lib/components/sliceby/SliceCard.svelte
# hmr update /src/routes/interface.svelte
# hmr update /src/routes/__layout.svelte
# 10:53:30 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:213:1 Unused CSS selector ".dragger"
# 10:53:30 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:228:0 Unused CSS selector ".dragger:hover"
# Transform failed with 1 error:
# /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/utils/requests.ts:1:0: ERROR: Unexpected "<<"
# Transform failed with 1 error:
# /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/utils/requests.ts:1:0: ERROR: Unexpected "<<"
# 10:53:30 AM [vite] Internal server error: Transform failed with 1 error:
# /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/utils/requests.ts:1:0: ERROR: Unexpected "<<"
#   Plugin: vite:esbuild
#   File: /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/utils/requests.ts
#
#   Unexpected "<<"
#   1  |  <<<<<<< HEAD
#      |  ^
#   2  |  import { global_stores, store_lock } from "$lib/components/blanks/stores";
#   3  |  import { get as get_store } from "svelte/store";
#
#       at failureErrorWithLog (/Users/eyubogln/code/meerkat/meerkat/interactive/app/node_modules/esbuild/lib/main.js:1615:15)
#       at /Users/eyubogln/code/meerkat/meerkat/interactive/app/node_modules/esbuild/lib/main.js:1404:29
#       at /Users/eyubogln/code/meerkat/meerkat/interactive/app/node_modules/esbuild/lib/main.js:669:9
#       at handleIncomingPacket (/Users/eyubogln/code/meerkat/meerkat/interactive/app/node_modules/esbuild/lib/main.js:766:9)
#       at Socket.readFromStdout (/Users/eyubogln/code/meerkat/meerkat/interactive/app/node_modules/esbuild/lib/main.js:635:7)
#       at Socket.emit (node:events:537:28)
#       at addChunk (node:internal/streams/readable:324:12)
#       at readableAddChunk (node:internal/streams/readable:297:9)
#       at Readable.push (node:internal/streams/readable:234:10)
#       at Pipe.onStreamRead (node:internal/stream_base_commons:190:23)
# 10:53:30 AM [vite] Internal server error: Transform failed with 1 error:
# /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/utils/requests.ts:1:0: ERROR: Unexpected "<<"
#   Plugin: vite:esbuild
#   File: /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/utils/requests.ts
#
#   Unexpected "<<"
#   1  |  <<<<<<< HEAD
#      |  ^
#   2  |  import { global_stores, store_lock } from "$lib/components/blanks/stores";
#   3  |  import { get as get_store } from "svelte/store";
#
#       at failureErrorWithLog (/Users/eyubogln/code/meerkat/meerkat/interactive/app/node_modules/esbuild/lib/main.js:1615:15)
#       at /Users/eyubogln/code/meerkat/meerkat/interactive/app/node_modules/esbuild/lib/main.js:1404:29
#       at /Users/eyubogln/code/meerkat/meerkat/interactive/app/node_modules/esbuild/lib/main.js:669:9
#       at handleIncomingPacket (/Users/eyubogln/code/meerkat/meerkat/interactive/app/node_modules/esbuild/lib/main.js:766:9)
#       at Socket.readFromStdout (/Users/eyubogln/code/meerkat/meerkat/interactive/app/node_modules/esbuild/lib/main.js:635:7)
#       at Socket.emit (node:events:537:28)
#       at addChunk (node:internal/streams/readable:324:12)
#       at readableAddChunk (node:internal/streams/readable:297:9)
#       at Readable.push (node:internal/streams/readable:234:10)
#       at Pipe.onStreamRead (node:internal/stream_base_commons:190:23)
# 10:54:43 AM [vite] hmr update /src/app.css
# hmr update /src/app.css
# hmr update /src/lib/component/match/Match.svelte
# hmr update /src/app.css
# hmr update /src/lib/components/sliceby/SliceCards.svelte
# hmr update /src/lib/TableView.svelte
# hmr update /src/app.css
# hmr update /src/lib/components/plot_header/PlotHeader.svelte
# hmr update /src/app.css
# hmr update /src/lib/components/match_header/MatchHeader.svelte
# hmr update /src/app.css
# hmr update /src/lib/components/column_select/ColumnSelect.svelte
# hmr update /src/app.css
# hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# hmr update /src/lib/components/sliceby/SliceCards.svelte
# hmr update /src/app.css
# hmr update /src/lib/components/sliceby/SliceCards.svelte
# hmr update /src/lib/components/sliceby/SliceCard.svelte
# hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# 10:54:43 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:213:1 Unused CSS selector ".dragger"
# 10:54:43 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:228:0 Unused CSS selector ".dragger:hover"
# Triggering store d24791cf83fe4fe78aa08c3d7fdfc581 image_id
# Triggering store d24791cf83fe4fe78aa08c3d7fdfc581 image_id
# 10:54:43 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:213:1 Unused CSS selector ".dragger"
# 10:54:43 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:228:0 Unused CSS selector ".dragger:hover"
# 10:58:28 AM [vite] hmr update /src/app.css
# hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# hmr update /src/routes/interface.svelte?svelte&type=style&lang.css
# 10:58:28 AM [vite] hmr update /src/lib/component/StoreComponent.svelte
# hmr update /src/app.css
# 10:58:28 AM [vite] hmr update /src/app.css
# hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# hmr update /src/routes/interface.svelte?svelte&type=style&lang.css
# 10:58:28 AM [vite] hmr update /src/lib/component/match/Match.svelte
# hmr update /src/app.css
# hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# hmr update /src/routes/interface.svelte?svelte&type=style&lang.css
# 10:58:28 AM [vite] page reload src/lib/api/llm.ts
# 10:58:28 AM [vite] hmr update /src/app.css
# hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# hmr update /src/routes/interface.svelte?svelte&type=style&lang.css
# 10:58:28 AM [vite] hmr update /src/lib/component/slicebycards/RowCard.svelte
# hmr update /src/app.css
# hmr update /src/lib/component/slicebycards/RowCard.svelte
# hmr update /src/app.css
# hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# hmr update /src/routes/interface.svelte?svelte&type=style&lang.css
# 10:58:28 AM [vite] hmr update /src/lib/component/slicebycards/SliceByCard.svelte
# hmr update /src/app.css
# hmr update /src/lib/component/slicebycards/SliceByCard.svelte
# hmr update /src/app.css
# hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# hmr update /src/routes/interface.svelte?svelte&type=style&lang.css
# 10:58:28 AM [vite] hmr update /src/lib/component/slicebycards/SliceByCards.svelte
# hmr update /src/app.css
# hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# hmr update /src/routes/interface.svelte?svelte&type=style&lang.css
# 10:58:28 AM [vite] hmr update /src/lib/component/table/Table.svelte
# hmr update /src/app.css
# hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# hmr update /src/routes/interface.svelte?svelte&type=style&lang.css
# 10:58:28 AM [vite] page reload src/lib/components/abstract/Block.svelte
# 10:58:28 AM [vite] page reload src/lib/components/abstract/BlockGroup.svelte
# 10:58:28 AM [vite] page reload src/lib/components/abstract/Interface.svelte
# 10:58:28 AM [vite] page reload src/lib/components/abstract/Operator.svelte
# 10:58:28 AM [vite] page reload src/lib/components/abstract/View.svelte
# 10:58:28 AM [vite] page reload src/lib/components/abstract/stores.js
# 10:58:28 AM [vite] hmr update /src/lib/component/StoreComponent.svelte
# hmr update /src/app.css
# hmr update /src/app.css
# hmr update /src/app.css
# hmr update /src/lib/component/match/Match.svelte
# hmr update /src/app.css
# hmr update /src/lib/components/sliceby/SliceCards.svelte
# hmr update /src/lib/TableView.svelte
# hmr update /src/app.css
# hmr update /src/lib/components/plot_header/PlotHeader.svelte
# hmr update /src/app.css
# hmr update /src/lib/components/match_header/MatchHeader.svelte
# hmr update /src/app.css
# hmr update /src/lib/components/column_select/ColumnSelect.svelte
# hmr update /src/app.css
# hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# hmr update /src/lib/components/sliceby/SliceCards.svelte
# hmr update /src/app.css
# hmr update /src/lib/components/sliceby/SliceCards.svelte
# hmr update /src/lib/components/sliceby/SliceCard.svelte
# hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# hmr update /src/app.css
# hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# 10:58:28 AM [vite] page reload src/lib/components/blocks/Block.svelte
# 10:58:28 AM [vite] page reload src/lib/components/blocks/Dummy.svelte
# 10:58:28 AM [vite] page reload src/lib/components/blocks/DummyBlock.svelte
# 10:58:28 AM [vite] page reload src/lib/components/blocks/DummyPlot.svelte
# 10:58:28 AM [vite] page reload src/lib/components/blocks/DummyTable.svelte
# 10:58:28 AM [vite] page reload src/lib/components/blocks/Everything.svelte
# 10:58:28 AM [vite] page reload src/lib/components/blocks/Filter.svelte
# 10:58:28 AM [vite] page reload src/lib/components/blocks/Gallery.svelte
# 10:58:28 AM [vite] page reload src/lib/components/blocks/NewBlock.svelte
# 10:58:28 AM [vite] page reload src/lib/components/blocks/stores.js
# 10:58:28 AM [vite] hmr update /src/lib/components/cell/basic/Basic.svelte
# hmr update /src/app.css
# 10:58:28 AM [vite] page reload src/lib/components/layout.svelte
# 10:58:28 AM [vite] page reload src/lib/components/lm/CategoryGenerator.svelte
# 10:58:28 AM [vite] page reload src/lib/components/lm/Node.svelte
# 10:58:28 AM [vite] page reload src/lib/components/lm/SchemaTree.svelte
# 10:58:28 AM [vite] page reload src/lib/utils/graph.ts
# 10:58:28 AM [vite] page reload src/routes/old_interface.svelte
# 10:58:28 AM [vite] page reload src/routes/tests/blocks/TestDummy.svelte
# 10:58:28 AM [vite] hmr update /src/app.css
# hmr update /src/lib/component/match/Match.svelte
# hmr update /src/app.css
# hmr update /src/lib/components/sliceby/SliceCards.svelte
# hmr update /src/lib/TableView.svelte
# hmr update /src/app.css
# hmr update /src/lib/components/plot_header/PlotHeader.svelte
# hmr update /src/app.css
# hmr update /src/lib/components/match_header/MatchHeader.svelte
# hmr update /src/app.css
# hmr update /src/lib/components/column_select/ColumnSelect.svelte
# hmr update /src/app.css
# hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# 10:58:28 AM [vite] hmr update /src/app.css
# hmr update /src/lib/components/sliceby/SliceCards.svelte
# hmr update /src/lib/components/sliceby/SliceCard.svelte
# 10:58:28 AM [vite] hmr update /src/lib/components/cell/Cell.svelte
# hmr update /src/app.css
# 10:58:28 AM [vite] hmr update /src/lib/components/common/Pill.svelte
# hmr update /src/app.css
# 10:58:29 AM [vite] hmr update /src/lib/components/row/RowCard.svelte
# hmr update /src/lib/components/row/RowCard.svelte
# 10:58:29 AM [vite] hmr update /src/lib/components/sliceby/SliceCard.svelte
# hmr update /src/lib/components/sliceby/SliceCard.svelte
# 10:58:29 AM [vite] hmr update /src/lib/components/sliceby/SliceCards.svelte
# 10:58:29 AM [vite] hmr update /src/app.css
# hmr update /src/app.css
# hmr update /src/lib/component/match/Match.svelte
# hmr update /src/app.css
# hmr update /src/lib/components/sliceby/SliceCards.svelte
# hmr update /src/lib/TableView.svelte
# hmr update /src/app.css
# hmr update /src/lib/components/plot_header/PlotHeader.svelte
# hmr update /src/app.css
# hmr update /src/lib/components/match_header/MatchHeader.svelte
# hmr update /src/app.css
# hmr update /src/lib/components/column_select/ColumnSelect.svelte
# hmr update /src/app.css
# hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# hmr update /src/lib/components/sliceby/SliceCards.svelte
# hmr update /src/app.css
# hmr update /src/lib/components/sliceby/SliceCards.svelte
# hmr update /src/lib/components/sliceby/SliceCard.svelte
# hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# 10:58:29 AM [vite] hmr update /src/routes/interface.svelte?svelte&type=style&lang.css
# hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# 10:58:29 AM [vite] page reload .svelte-kit/generated/client-manifest.js
# 10:58:29 AM [vite] hmr update /src/lib/components/gallery/Gallery.svelte?svelte&type=style&lang.css
# hmr update /src/lib/components/gallery/Gallery.svelte
# hmr update /src/routes/__layout.svelte
# 10:58:29 AM [vite] hmr update /src/lib/components/gallery/Card.svelte
# hmr update /src/routes/__layout.svelte
# 10:58:29 AM [vite] hmr update /src/lib/TableView.svelte
# hmr update /src/routes/__layout.svelte
# 10:58:29 AM [vite] hmr update /src/lib/components/table/Table.svelte?svelte&type=style&lang.css
# hmr update /src/lib/components/table/Table.svelte
# hmr update /src/routes/__layout.svelte
# 10:58:30 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/TableView.svelte:164:1 Unused CSS selector ".dark .table-view"
# 10:58:30 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/sliceby/SliceCard.svelte:9:11 SliceCard has unused export property 'datapanel_id'. If it is for external reference only, please consider using `export const datapanel_id`
# 10:58:30 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/plot_header/PlotHeader.svelte:8:11 PlotHeader has unused export property 'rows_promise'. If it is for external reference only, please consider using `export const rows_promise`
# 10:58:30 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/TableView.svelte:164:1 Unused CSS selector ".dark .table-view"
# 10:58:30 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/sliceby/SliceCard.svelte:9:11 SliceCard has unused export property 'datapanel_id'. If it is for external reference only, please consider using `export const datapanel_id`
# 10:58:30 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/plot_header/PlotHeader.svelte:8:11 PlotHeader has unused export property 'rows_promise'. If it is for external reference only, please consider using `export const rows_promise`
# 10:58:31 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/TableView.svelte:164:1 Unused CSS selector ".dark .table-view"
# 10:58:31 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/match_header/MatchHeader.svelte:104:1 Unused CSS selector ".list-container"
# 10:58:31 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/gallery/Gallery.svelte:112:1 Unused CSS selector ".dark .panel"
# 10:58:31 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/table/Table.svelte:102:1 Unused CSS selector ".dark .table"
# ...
# 10:58:34 AM [vite] page reload src/lib/components/abstract/View.svelte
# 10:58:34 AM [vite] hmr update /src/app.css
# hmr update /src/lib/component/match/Match.svelte
# hmr update /src/app.css
# hmr update /src/lib/components/sliceby/SliceCards.svelte
# hmr update /src/lib/TableView.svelte
# hmr update /src/app.css
# hmr update /src/lib/components/plot_header/PlotHeader.svelte
# hmr update /src/app.css
# hmr update /src/lib/components/match_header/MatchHeader.svelte
# hmr update /src/app.css
# hmr update /src/lib/components/column_select/ColumnSelect.svelte
# hmr update /src/app.css
# 10:58:34 AM [vite] page reload src/lib/api/llm.ts
# 10:58:34 AM [vite] hmr update /src/app.css
# hmr update /src/lib/components/sliceby/SliceCards.svelte
# hmr update /src/lib/components/sliceby/SliceCard.svelte
# 10:58:34 AM [vite] hmr update /src/lib/component/StoreComponent.svelte
# hmr update /src/app.css
# 10:58:34 AM [vite] page reload src/lib/component/filter/Filter.svelte
# 10:58:34 AM [vite] page reload src/lib/component/filter/Filter.svelte
# 10:58:34 AM [vite] page reload src/lib/component/gallery/Gallery.svelte
# 10:58:34 AM [vite] page reload src/lib/component/gallery/Gallery.svelte
# 10:58:34 AM [vite] hmr update /src/lib/component/match/Match.svelte
# hmr update /src/app.css
# hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# hmr update /src/routes/interface.svelte?svelte&type=style&lang.css
# 10:58:34 AM [vite] hmr update /src/lib/component/match/Match.svelte
# hmr update /src/app.css
# 10:58:34 AM [vite] page reload src/lib/component/plot/Plot.svelte
# 10:58:34 AM [vite] page reload src/lib/component/plot/Plot.svelte
# 10:58:34 AM [vite] hmr update /src/lib/component/slicebycards/RowCard.svelte
# hmr update /src/app.css
# hmr update /src/lib/component/slicebycards/RowCard.svelte
# hmr update /src/app.css
# hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# hmr update /src/routes/interface.svelte?svelte&type=style&lang.css
# 10:58:34 AM [vite] hmr update /src/lib/component/slicebycards/RowCard.svelte
# hmr update /src/app.css
# hmr update /src/lib/component/slicebycards/RowCard.svelte
# hmr update /src/app.css
# 10:58:34 AM [vite] hmr update /src/lib/component/slicebycards/SliceByCard.svelte
# hmr update /src/app.css
# hmr update /src/lib/component/slicebycards/SliceByCard.svelte
# hmr update /src/app.css
# hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# hmr update /src/routes/interface.svelte?svelte&type=style&lang.css
# 10:58:34 AM [vite] hmr update /src/lib/component/slicebycards/SliceByCard.svelte
# hmr update /src/app.css
# hmr update /src/lib/component/slicebycards/SliceByCard.svelte
# hmr update /src/app.css
# 10:58:34 AM [vite] hmr update /src/lib/component/slicebycards/SliceByCards.svelte
# hmr update /src/app.css
# hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# hmr update /src/routes/interface.svelte?svelte&type=style&lang.css
# 10:58:34 AM [vite] hmr update /src/lib/component/slicebycards/SliceByCards.svelte
# hmr update /src/app.css
# 10:58:34 AM [vite] hmr update /src/lib/component/table/Table.svelte
# hmr update /src/app.css
# hmr update /src/routes/interface.svelte
# hmr update /src/app.css
# hmr update /src/routes/interface.svelte?svelte&type=style&lang.css
# 10:58:34 AM [vite] hmr update /src/lib/component/table/Table.svelte
# hmr update /src/app.css
# 10:58:34 AM [vite] page reload src/lib/components/abstract/Block.svelte
# 10:58:34 AM [vite] page reload src/lib/components/abstract/BlockGroup.svelte
# 10:58:34 AM [vite] page reload src/lib/components/abstract/Interface.svelte
# 10:58:34 AM [vite] page reload src/lib/components/abstract/stores.js
# 10:58:34 AM [vite] hmr update /src/lib/component/StoreComponent.svelte
# hmr update /src/app.css
# hmr update /src/app.css
# hmr update /src/app.css
# hmr update /src/lib/component/match/Match.svelte
# hmr update /src/app.css
# hmr update /src/lib/components/sliceby/SliceCards.svelte
# hmr update /src/lib/TableView.svelte
# hmr update /src/app.css
# hmr update /src/lib/components/plot_header/PlotHeader.svelte
# hmr update /src/app.css
# hmr update /src/lib/components/match_header/MatchHeader.svelte
# hmr update /src/app.css
# hmr update /src/lib/components/column_select/ColumnSelect.svelte
# hmr update /src/app.css
# hmr update /src/lib/components/sliceby/SliceCards.svelte
# hmr update /src/app.css
# hmr update /src/lib/components/sliceby/SliceCards.svelte
# hmr update /src/lib/components/sliceby/SliceCard.svelte
# hmr update /src/app.css
# 10:58:34 AM [vite] page reload src/lib/components/blocks/Block.svelte
# 10:58:34 AM [vite] page reload src/lib/components/blocks/Dummy.svelte
# 10:58:34 AM [vite] page reload src/lib/components/blocks/DummyBlock.svelte
# 10:58:34 AM [vite] page reload src/lib/components/blocks/DummyPlot.svelte
# 10:58:34 AM [vite] page reload src/lib/components/blocks/DummyTable.svelte
# 10:58:34 AM [vite] page reload src/lib/components/blocks/Everything.svelte
# 10:58:34 AM [vite] page reload src/lib/components/blocks/Filter.svelte
# 10:58:34 AM [vite] page reload src/lib/components/blocks/Gallery.svelte
# 10:58:34 AM [vite] page reload src/lib/components/blocks/NewBlock.svelte
# 10:58:34 AM [vite] page reload src/lib/components/blocks/stores.js
# 10:58:34 AM [vite] hmr update /src/lib/components/cell/Cell.svelte
# hmr update /src/app.css
# 10:58:34 AM [vite] hmr update /src/lib/components/cell/basic/Basic.svelte
# hmr update /src/app.css
# 10:58:34 AM [vite] hmr update /src/lib/components/common/Pill.svelte
# hmr update /src/app.css
# 10:58:34 AM [vite] page reload src/lib/components/layout.svelte
# 10:58:34 AM [vite] page reload src/lib/components/lm/CategoryGenerator.svelte
# 10:58:34 AM [vite] page reload src/lib/components/lm/Node.svelte
# 10:58:34 AM [vite] page reload src/lib/components/lm/SchemaTree.svelte
# 10:58:34 AM [vite] page reload src/lib/utils/graph.ts
# 10:58:34 AM [vite] hmr update /src/app.css
# hmr update /src/app.css
# hmr update /src/lib/component/match/Match.svelte
# hmr update /src/app.css
# hmr update /src/lib/components/sliceby/SliceCards.svelte
# hmr update /src/lib/TableView.svelte
# hmr update /src/app.css
# hmr update /src/lib/components/plot_header/PlotHeader.svelte
# hmr update /src/app.css
# hmr update /src/lib/components/match_header/MatchHeader.svelte
# hmr update /src/app.css
# hmr update /src/lib/components/column_select/ColumnSelect.svelte
# hmr update /src/app.css
# hmr update /src/lib/components/sliceby/SliceCards.svelte
# hmr update /src/app.css
# hmr update /src/lib/components/sliceby/SliceCards.svelte
# hmr update /src/lib/components/sliceby/SliceCard.svelte
# 10:58:35 AM [vite] page reload src/routes/old_interface.svelte
# 10:58:35 AM [vite] page reload src/routes/tests/blocks/TestDummy.svelte
# 10:58:35 AM [vite] page reload .svelte-kit/generated/client-manifest.js
# 10:58:35 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/sliceby/SliceCard.svelte:9:11 SliceCard has unused export property 'datapanel_id'. If it is for external reference only, please consider using `export const datapanel_id`
# 10:58:35 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/table/Table.svelte:102:1 Unused CSS selector ".dark .table"
# 10:58:35 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/match_header/MatchHeader.svelte:104:1 Unused CSS selector ".list-container"
# 10:58:35 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/gallery/Gallery.svelte:112:1 Unused CSS selector ".dark .panel"
# 10:58:35 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/filter_header/FilterHeader.svelte:133:1 Unused CSS selector ".list-container"
# 10:58:35 AM [vite] Internal server error: Failed to resolve import "../row/RowCard.svelte" from "src/lib/components/sliceby/SliceCard.svelte". Does the file exist?
#   Plugin: vite:import-analysis
#   File: /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/sliceby/SliceCard.svelte
#   41 |  import { api_url } from '../../../routes/network/stores';
#   42 |  import { get_rows } from '$lib/api/sliceby';
#   43 |  import RowCard from '../row/RowCard.svelte';
#      |                       ^
#   44 |  import LoadButton from '../common/LoadButton.svelte';
#   45 |  import Pill from '$lib/components/common/Pill.svelte';
#       at formatError (file:///Users/eyubogln/code/meerkat/meerkat/interactive/app/node_modules/vite/dist/node/chunks/dep-c6273c7a.js:35035:46)
#       at TransformContext.error (file:///Users/eyubogln/code/meerkat/meerkat/interactive/app/node_modules/vite/dist/node/chunks/dep-c6273c7a.js:35031:19)
#       at normalizeUrl (file:///Users/eyubogln/code/meerkat/meerkat/interactive/app/node_modules/vite/dist/node/chunks/dep-c6273c7a.js:40172:33)
#       at async TransformContext.transform (file:///Users/eyubogln/code/meerkat/meerkat/interactive/app/node_modules/vite/dist/node/chunks/dep-c6273c7a.js:40306:47)
#       at async Object.transform (file:///Users/eyubogln/code/meerkat/meerkat/interactive/app/node_modules/vite/dist/node/chunks/dep-c6273c7a.js:35284:30)
#       at async loadAndTransform (file:///Users/eyubogln/code/meerkat/meerkat/interactive/app/node_modules/vite/dist/node/chunks/dep-c6273c7a.js:39803:29)
# Cannot read properties of undefined (reading 'url')
# 10:58:35 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/row/RowCard.svelte:21:11 RowCard has unused export property 'layout'. If it is for external reference only, please consider using `export const layout`
# 10:58:35 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/row/RowCard.svelte:24:11 RowCard has unused export property 'card_flex_grow'. If it is for external reference only, please consider using `export const card_flex_grow`
# 10:58:35 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/row/RowCard.svelte:53:11 RowCard has unused export property 'main_modal'. If it is for external reference only, please consider using `export const main_modal`
# 10:58:35 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/common/Toggle.svelte:31:0 Unused CSS selector ".dark .label"
# 10:58:35 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/common/Toggle.svelte:74:1 Unused CSS selector ".dark .toggle"
# Sourcemap for "/Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/row/RowCard.svelte" points to missing source files
# 10:58:35 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/plot_header/PlotHeader.svelte:8:11 PlotHeader has unused export property 'rows_promise'. If it is for external reference only, please consider using `export const rows_promise`
# 10:58:35 AM [vite] hmr update /src/lib/TableView.svelte
# hmr update /src/routes/__layout.svelte
# 10:58:35 AM [vite] hmr update /src/lib/components/gallery/Card.svelte
# hmr update /src/routes/__layout.svelte
# 10:58:35 AM [vite] hmr update /src/lib/components/gallery/Gallery.svelte?svelte&type=style&lang.css
# hmr update /src/lib/components/gallery/Gallery.svelte
# hmr update /src/routes/__layout.svelte
# 10:58:35 AM [vite] hmr update /src/lib/components/table/Table.svelte?svelte&type=style&lang.css
# hmr update /src/lib/components/table/Table.svelte
# hmr update /src/routes/__layout.svelte
# 10:58:35 AM [vite] hmr update /src/routes/interface.svelte?svelte&type=style&lang.css
# hmr update /src/routes/interface.svelte
# hmr update /src/routes/__layout.svelte
# 10:58:36 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/gallery/Gallery.svelte:138:1 Unused CSS selector ".dark .panel"
# 10:58:36 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/match_header/MatchHeader.svelte:104:1 Unused CSS selector ".list-container"
# 10:58:36 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:213:1 Unused CSS selector ".dragger"
# 10:58:36 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:228:0 Unused CSS selector ".dragger:hover"
# 10:58:36 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/gallery/Card.svelte:104:1 Unused CSS selector ".card"
# 10:58:36 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/gallery/Card.svelte:114:1 Unused CSS selector ".dark .card"
# 10:58:36 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/gallery/Card.svelte:149:1 Unused CSS selector ".subcontent"
# 10:58:36 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/gallery/Card.svelte:171:1 Unused CSS selector ".subcontent:hover"
# 10:58:36 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/gallery/Card.svelte:104:1 Unused CSS selector ".card"
# 10:58:36 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/gallery/Card.svelte:114:1 Unused CSS selector ".dark .card"
# 10:58:36 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/gallery/Card.svelte:149:1 Unused CSS selector ".subcontent"
# 10:58:36 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/gallery/Card.svelte:171:1 Unused CSS selector ".subcontent:hover"
# 10:58:36 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/components/gallery/Gallery.svelte:138:1 Unused CSS selector ".dark .panel"
# Triggering store d24791cf83fe4fe78aa08c3d7fdfc581 image_id
# Triggering store d24791cf83fe4fe78aa08c3d7fdfc581 image_id
# 10:58:37 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:213:1 Unused CSS selector ".dragger"
# 10:58:37 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:228:0 Unused CSS selector ".dragger:hover"
# 10:58:37 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/component/slicebycards/RowCard.svelte:21:11 RowCard has unused export property 'layout'. If it is for external reference only, please consider using `export const layout`
# 10:58:37 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/component/slicebycards/RowCard.svelte:24:11 RowCard has unused export property 'card_flex_grow'. If it is for external reference only, please consider using `export const card_flex_grow`
# 10:58:37 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/component/slicebycards/RowCard.svelte:53:11 RowCard has unused export property 'main_modal'. If it is for external reference only, please consider using `export const main_modal`
# 10:58:37 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/component/slicebycards/RowCard.svelte:21:11 RowCard has unused export property 'layout'. If it is for external reference only, please consider using `export const layout`
# 10:58:37 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/component/slicebycards/RowCard.svelte:24:11 RowCard has unused export property 'card_flex_grow'. If it is for external reference only, please consider using `export const card_flex_grow`
# 10:58:37 AM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/component/slicebycards/RowCard.svelte:53:11 RowCard has unused export property 'main_modal'. If it is for external reference only, please consider using `export const main_modal`
# 11:38:34 AM [vite] hmr update /src/lib/components/gallery/Gallery.svelte
# hmr update /src/routes/__layout.svelte
# Browser:  false
# SSR
# Browser:  false
# SSR
# Browser:  false
# SSR
# Triggering store d24791cf83fe4fe78aa08c3d7fdfc581 image_id
# Triggering store d24791cf83fe4fe78aa08c3d7fdfc581 image_id

# %%
indian_dp = indian_dp.sort(by="v6_fnmr", ascending=False)
cb = indian_dp.clusterby(by="image")
cb.gui.cards(
    main_column="image", 
    tag_columns=["v6_fnmr", "ethnicity"],
    aggregations={
        "Mean FNMR": lambda x: x["v6_fnmr"].mean(),
        "STD FNMR": lambda x: x["v6_fnmr"].std(),
        "Size": len,
    }
)

# %% [markdown]
# ## Diving deeper
#
# In practice, the slices discovered in the previous section should serve as inspiration for further exploration. One great way to quickly continue exploring other slices is via the plot interface. Unlike standard plotting interfaces, you can actually manipulate the axes and add labels for columns that don’t yet exist.

# %%
indian_dp.gui.table()
# Out:
#         <iframe
#             width="100%"
#             height="1000"
#             src="http://localhost:7861/interface?id=8221c948d71e4d9eac676c06249c90b0"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# In here.
# http://127.0.0.1:7860
# Response {
#   [Symbol(realm)]: null,
#   [Symbol(state)]: {
#     aborted: false,
#     rangeRequested: false,
#     timingAllowPassed: true,
#     requestIncludesCredentials: true,
#     type: 'default',
#     status: 200,
#     timingInfo: {
#       startTime: 240731.8119159937,
#       redirectStartTime: 240731.8119159937,
#       redirectEndTime: 240733.22329103947,
#       postRedirectStartTime: 240733.22329103947,
#       finalServiceWorkerStartTime: 0,
#       finalNetworkResponseStartTime: 0,
#       finalNetworkRequestStartTime: 0,
#       endTime: 0,
#       encodedBodySize: 0,
#       decodedBodySize: 0,
#       finalConnectionTimingInfo: null
#     },
#     cacheState: '',
#     statusText: 'OK',
#     headersList: HeadersList {
#       [Symbol(headers map)]: [Map],
#       [Symbol(headers map sorted)]: null
#     },
#     urlList: [ [URL], [URL] ],
#     body: { stream: undefined }
#   },
#   [Symbol(headers)]: HeadersList {
#     [Symbol(headers map)]: Map(4) {
#       'date' => 'Thu, 18 Aug 2022 21:26:52 GMT',
#       'server' => 'uvicorn',
#       'content-length' => '100',
#       'content-type' => 'application/json'
#     },
#     [Symbol(headers map sorted)]: null
#   }
# }
# {
#   component: 'table',
#   props: {
#     type: 'table',
#     nrows: 10280,
#     dp: '297c7baaf17f400d82ea0090475989d4'
#   }
# }
# http://127.0.0.1:7860/dp/297c7baaf17f400d82ea0090475989d4/rows
# start: 0
# end: 100
# indices: undefined
# columns: undefined
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
slice_idx = 0
indian_dp[f"slice_{slice_idx}"] = indian_dp["MixtureSlicer(image,v6_fnmr)"][:, slice_idx]

# %% [markdown]
# **Demo goals.** The purpose of this demo is to collect feedback on the tools we’re developing. We would like to understand how they can be made more useful for the task of auditing machine learning models. We are still in very early days, so your concerns/suggestions will inform how we move forward. So, please be candid – any and all feedback is appreciated. To help guide the discussion, we’ve included below some specific questions that are particularly front-of-mind for us, but feel free to diverge from these topics:
#
# ❓ **Questions to Guide Feedback.**
#
# *Did you learn something new about the behavior of this algorithm? Did you find slices that you would flag for bias concerns?*
#
# *Are these slices actionable? What would that action be? How would you address this slice?*
#
# *Did the slices you found seem important/interesting to you? If not, what kinds of slices do you think would be important to find?* *Why do you supect it is hard to find those slices?*
#
# Interface Questions
#
# - *Did you find the natural language descriptions useful for describing discovered slices, or did just looking through the pictures suffice? Did you trust the descriptions? Concrete examples (ideally with screenshots) would be great here.*
# - *Did you use natural language to test out new slices? What types of prompts did you write? Did you trust the results?*
# - *The main interface we currently provide for creating new slices is with natural language? Are there other interfaces you would find useful (*e.g. *scribbling, cropping, upload images)? Were there slices you would’ve liked to test, but weren’t able to?*
# - *Did you trust the statistics computed on the slices? How can we improve trust? *
#
# Implementation Questions:
#
# - *For the types of datasets you work with, do you think it would be easy to store it in a Meerkat DataPanel? Does this data structure feel like a good fit? How could it be improved to better support your data?*
# - *Are there views, plots, visualizations of the data that you were craving?*
# - *Was it easy to use Meerkat in a Jupyter Notebook?*
