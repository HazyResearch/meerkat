# %%
# %load_ext autoreload
# %autoreload 2

# %%
# setup
import pathlib
base_dir = pathlib.Path("/Users/eyubogln/.meerkat/datasets/rfw/")

# %% [markdown]
# # Auditing Machine Learning Models with Meerkat
#
#
# In this demo, we’ll be using the Racial Faces in the Wild (RFW) dataset to audit AWS’s FaceCompare API. We provide predictions from the API on this dataset. Your task is to analyze model performance on this dataset and identify slices where the model is performing particularly poorly or particularly well.
#
# In order to audit the API, we’ll be using a tool we’re developing that helps data scientists help wrangle and analyze unstructured data: it’s called [Meerkat](https://meerkat.readthedocs.io/en/latest/guide/guide.html). Under the hood, it uses techniques like those described in [Domino](https://meerkat.readthedocs.io/en/latest/guide/guide.html) to identifying underperforming populations in machine learning datasets.
#
# So, let’s import the Python package and get started!

# %%
import meerkat as mk

# %% [markdown]
# ## Loading Data
#
# Meerkat provides a [registry](https://meerkat.readthedocs.io/en/dev/datasets/datasets.html) of commonly used datasets, like RFW, which allows us to load the data into memory with one line of code.  We can then merge the dataset with a CSV containing the model predictions.
#
# In memory, the dataset and model predictions are stored in a [Meerkat DataPanel](https://meerkat.readthedocs.io/en/latest/guide/data_structures.html). A `DataPanel` is in many ways just like a Pandas DataFrame: it’s a tabular data structure made up of columns. Unlike a DataFrame though, the `DataPanel` is designed for unstructured data types like images and audio. As you can see in the table visualization below, there’s a column for the image, the false non-match rate (FNMR), id etc.

# %%
dp = mk.get("rfw")
dp.head(3)
# Out:
# DataPanel(nrows: 3, ncols: 4)

# %% [markdown]
# **Loading CompareFaces Errors**. CompareFaces is an operation in Amazon Rekognition that predicts whether two images are taken of the same person. We've applied CompareFaces v6 (an AWS service) to the RFW dataset and stored the error rates for each image in the file `facecompare_v6_errors.csv`. Specifically, we've computed the *False Non-Match Rate* (FNMR) for each image, a measure of how often the model falsely predicts that two images are **not** of the same person.
#
# <div>
# <img src="fnmr.png" width="400"/>
# </div>
#
# We can load these error rates into our DataPanel with a single `DataPanel.merge` call which is equivalent to a `merge` in Pandas or a `join` in SQL. After doing this, we can see that the FNMR for each image is stored in the new `v6_fnmr` column.

# %%
dp = dp.merge(
	mk.DataPanel.from_csv(base_dir / "themis/facecompare_v6_errors.csv"),
	on="image_id",
)
dp.head(3)
# Out:
# DataPanel(nrows: 3, ncols: 5)

# %% [markdown]
# There are a number of operations that can be performed on a `DataPanel`, for example, we can use `sample` to randomly shuffle the dataset.

# %%
dp = dp.sample(frac=1, replace=False)

# %% [markdown]
# ## Exploring the Dataset
#
# To help with explore datasets with unstructured data types (*e.g.* images), Meerkat allows you to spin up interactive GUIs from within your notebook. These visualizations allow you to efficiently explore large image, audio, and video datasets.
#
# Note that the visualizations are highly customizable. There are a few different interface types (*e.g.  “*gallery”, “table”, “plot”) that can be customized from within the notebook.  See the documentation for a full list of interfaces.
#
# First though, we'll have to execute the two cells below to launch the interactive mode.

# %%
network, register_api = mk.interactive_mode()
# Out:
# > src@0.0.1 dev
# > vite dev "--port" "7861"
#
#
#   VITE v3.0.3  ready in 408 ms
#
#   ➜  Local:   http://localhost:7861/
#   ➜  Network: use --host to expose

# %%
register_api()
# Out:
#         <iframe
#             width="1"
#             height="1"
#             src="http://localhost:7861/network/register?api=http://127.0.0.1:7860"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# 6:00:45 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:213:1 Unused CSS selector ".dragger"
# 6:00:46 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:228:0 Unused CSS selector ".dragger:hover"

# %% [markdown]
# To begin, understanding the errors, we'll sort the DataPanel by the FNMR column and then launch a new interface.

# %%
dp = dp.sort(by="v6_fnmr", ascending=False) 

dp.gui.table(id_column="image_id")
# Out:
#         <iframe
#             width="100%"
#             height="1000"
#             src="http://localhost:7861/interface?id=04e7627200244ca7a107f8bedf067531"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# Triggering store 9ca36751ca0f4c5eba5d09069a67a18d image_id
# 6:00:47 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:213:1 Unused CSS selector ".dragger"
# 6:00:47 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:228:0 Unused CSS selector ".dragger:hover"
# 6:01:17 PM [vite] hmr update /src/lib/components/cell/basic/Basic.svelte
# hmr update /src/app.css
# 6:01:17 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:213:1 Unused CSS selector ".dragger"
# 6:01:17 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:228:0 Unused CSS selector ".dragger:hover"
# 6:01:24 PM [vite] hmr update /src/lib/components/cell/basic/Basic.svelte
# hmr update /src/routes/__layout.svelte
# 6:01:24 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:213:1 Unused CSS selector ".dragger"
# 6:01:24 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:228:0 Unused CSS selector ".dragger:hover"
# Triggering store 9ca36751ca0f4c5eba5d09069a67a18d image_id
# 6:01:25 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:213:1 Unused CSS selector ".dragger"
# 6:01:25 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:228:0 Unused CSS selector ".dragger:hover"
# 6:01:29 PM [vite] hmr update /src/lib/components/cell/basic/Basic.svelte
# hmr update /src/routes/__layout.svelte
# 6:01:30 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:213:1 Unused CSS selector ".dragger"
# 6:01:30 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:228:0 Unused CSS selector ".dragger:hover"

# %% [markdown]
# ## Computing global metrics
# Next we’ll  compute some average metrics across the entire dataset to get a sense of how the model is performing globally.

# %%
global_fnmr = dp["v6_fnmr"].mean()
print(f"Global False Non-Match Rate: {global_fnmr: .2%}")
# Out:
# Global False Non-Match Rate:  2.28%

# %% [markdown]
# ## Computing group statistics
#
# RFW provides annotations for limited set of high-level racial groups. In ths section, we’ll see how performance varies when stratifying by these groups. To do so, we’ll use `mk.groupby`.

# %%
gb = dp.groupby("ethnicity")
gb["v6_fnmr"].mean()
# Out:
# DataPanel(nrows: 4, ncols: 2)

# %%
type(dp["v6_fnmr"][0].item() )
# Out:
# float

# %% [markdown]
# We can also visualize the groups in a `GroupBy` with the `cards` interface:

# %%
gb.gui.cards(
    main_column="image", 
    tag_columns=["v6_fnmr"],
    aggregations={
        "Mean FNMR": lambda x: x["v6_fnmr"].mean(),
        "STD FNMR": lambda x: x["v6_fnmr"].std(),
        "Size": len,
    }
)
# Out:
#         <iframe
#             width="100%"
#             height="1000"
#             src="http://localhost:7861/interface?id=78b1a95dd32844f192d1deb89f04d3a0"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# Triggering store 9ca36751ca0f4c5eba5d09069a67a18d image_id
# 6:02:03 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:213:1 Unused CSS selector ".dragger"
# 6:02:03 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:228:0 Unused CSS selector ".dragger:hover"
# 6:02:03 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/component/slicebycards/RowCard.svelte:21:11 RowCard has unused export property 'layout'. If it is for external reference only, please consider using `export const layout`
# 6:02:03 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/component/slicebycards/RowCard.svelte:24:11 RowCard has unused export property 'card_flex_grow'. If it is for external reference only, please consider using `export const card_flex_grow`
# 6:02:03 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/component/slicebycards/RowCard.svelte:53:11 RowCard has unused export property 'main_modal'. If it is for external reference only, please consider using `export const main_modal`
# 6:04:45 PM [vite] page reload src/lib/components/sliceby/SliceCard.svelte
# Triggering store 9ca36751ca0f4c5eba5d09069a67a18d image_id
# Triggering store 9ca36751ca0f4c5eba5d09069a67a18d image_id
# 6:05:20 PM [vite] page reload src/lib/components/sliceby/SliceCard.svelte
# Triggering store 9ca36751ca0f4c5eba5d09069a67a18d image_id
# Triggering store 9ca36751ca0f4c5eba5d09069a67a18d image_id
# 6:05:56 PM [vite] hmr update /src/lib/component/slicebycards/SliceByCard.svelte
# hmr update /src/app.css
# 6:08:26 PM [vite] hmr update /src/lib/component/slicebycards/SliceByCard.svelte
# hmr update /src/app.css
# 6:11:03 PM [vite] hmr update /src/lib/components/common/Pill.svelte
# hmr update /src/app.css
# src/lib/components/cell/basic/Basic.svelte:5:8 - error TS1005: '(' expected.
#
# 5     if dtype
#          ~~~~~
# src/lib/components/cell/basic/Basic.svelte:8:5 - error TS1005: ')' expected.
#
# 8     if (dtype === "float") {
#       ~~
#
# 6:15:40 PM [vite] hmr update /src/lib/components/cell/basic/Basic.svelte
# hmr update /src/app.css
# 6:15:54 PM [vite] hmr update /src/lib/components/common/Pill.svelte
# hmr update /src/app.css
# 6:15:54 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:213:1 Unused CSS selector ".dragger"
# 6:15:54 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:228:0 Unused CSS selector ".dragger:hover"
# Triggering store 9ca36751ca0f4c5eba5d09069a67a18d image_id
# 6:15:54 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:213:1 Unused CSS selector ".dragger"
# 6:15:54 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:228:0 Unused CSS selector ".dragger:hover"
# 6:15:55 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/component/slicebycards/RowCard.svelte:21:11 RowCard has unused export property 'layout'. If it is for external reference only, please consider using `export const layout`
# 6:15:55 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/component/slicebycards/RowCard.svelte:24:11 RowCard has unused export property 'card_flex_grow'. If it is for external reference only, please consider using `export const card_flex_grow`
# 6:15:55 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/component/slicebycards/RowCard.svelte:53:11 RowCard has unused export property 'main_modal'. If it is for external reference only, please consider using `export const main_modal`
# 6:15:55 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/component/slicebycards/RowCard.svelte:21:11 RowCard has unused export property 'layout'. If it is for external reference only, please consider using `export const layout`
# 6:15:55 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/component/slicebycards/RowCard.svelte:24:11 RowCard has unused export property 'card_flex_grow'. If it is for external reference only, please consider using `export const card_flex_grow`
# 6:15:55 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/component/slicebycards/RowCard.svelte:53:11 RowCard has unused export property 'main_modal'. If it is for external reference only, please consider using `export const main_modal`
# 6:15:58 PM [vite] hmr update /src/lib/components/common/Pill.svelte
# hmr update /src/routes/__layout.svelte
# 6:15:59 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:213:1 Unused CSS selector ".dragger"
# 6:15:59 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:228:0 Unused CSS selector ".dragger:hover"
# Triggering store 9ca36751ca0f4c5eba5d09069a67a18d image_id
# 6:15:59 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:213:1 Unused CSS selector ".dragger"
# 6:15:59 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:228:0 Unused CSS selector ".dragger:hover"
# 6:16:21 PM [vite] hmr update /src/lib/components/cell/basic/Basic.svelte
# hmr update /src/routes/__layout.svelte
# src/lib/components/cell/basic/Basic.svelte:6:59 - error TS1002: Unterminated string literal.
#
# 6         console.log("dtype is undefined: ", typeof data");
#
# src/lib/components/cell/basic/Basic.svelte:6:56 - error TS1005: ',' expected.
#
# 6         console.log("dtype is undefined: ", typeof data");
#                                                          ~~~
# src/lib/components/cell/basic/Basic.svelte:7:9 - error TS1005: ',' expected.
#
# 7         if(typeof data === "number") {
#           ~~
#
# 6:16:48 PM [vite] hmr update /src/lib/components/cell/basic/Basic.svelte
# hmr update /src/app.css
# 6:16:48 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:213:1 Unused CSS selector ".dragger"
# 6:16:48 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:228:0 Unused CSS selector ".dragger:hover"
# Triggering store 9ca36751ca0f4c5eba5d09069a67a18d image_id
# Triggering store 9ca36751ca0f4c5eba5d09069a67a18d image_id
# 6:16:49 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:213:1 Unused CSS selector ".dragger"
# 6:16:49 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:228:0 Unused CSS selector ".dragger:hover"
# 6:16:49 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/component/slicebycards/RowCard.svelte:21:11 RowCard has unused export property 'layout'. If it is for external reference only, please consider using `export const layout`
# 6:16:49 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/component/slicebycards/RowCard.svelte:24:11 RowCard has unused export property 'card_flex_grow'. If it is for external reference only, please consider using `export const card_flex_grow`
# 6:16:49 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/component/slicebycards/RowCard.svelte:53:11 RowCard has unused export property 'main_modal'. If it is for external reference only, please consider using `export const main_modal`
# 6:16:49 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/component/slicebycards/RowCard.svelte:21:11 RowCard has unused export property 'layout'. If it is for external reference only, please consider using `export const layout`
# 6:16:49 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/component/slicebycards/RowCard.svelte:24:11 RowCard has unused export property 'card_flex_grow'. If it is for external reference only, please consider using `export const card_flex_grow`
# 6:16:49 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/component/slicebycards/RowCard.svelte:53:11 RowCard has unused export property 'main_modal'. If it is for external reference only, please consider using `export const main_modal`
# 6:17:17 PM [vite] hmr update /src/lib/components/cell/basic/Basic.svelte
# hmr update /src/routes/__layout.svelte
# 6:19:49 PM [vite] hmr update /src/lib/component/slicebycards/SliceByCard.svelte
# hmr update /src/app.css
# 6:19:49 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:213:1 Unused CSS selector ".dragger"
# 6:19:49 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:228:0 Unused CSS selector ".dragger:hover"
# 6:19:49 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/component/slicebycards/RowCard.svelte:21:11 RowCard has unused export property 'layout'. If it is for external reference only, please consider using `export const layout`
# 6:19:49 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/component/slicebycards/RowCard.svelte:24:11 RowCard has unused export property 'card_flex_grow'. If it is for external reference only, please consider using `export const card_flex_grow`
# 6:19:49 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/component/slicebycards/RowCard.svelte:53:11 RowCard has unused export property 'main_modal'. If it is for external reference only, please consider using `export const main_modal`
# 6:19:49 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/component/slicebycards/RowCard.svelte:21:11 RowCard has unused export property 'layout'. If it is for external reference only, please consider using `export const layout`
# 6:19:49 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/component/slicebycards/RowCard.svelte:24:11 RowCard has unused export property 'card_flex_grow'. If it is for external reference only, please consider using `export const card_flex_grow`
# 6:19:49 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/lib/component/slicebycards/RowCard.svelte:53:11 RowCard has unused export property 'main_modal'. If it is for external reference only, please consider using `export const main_modal`
# Triggering store 9ca36751ca0f4c5eba5d09069a67a18d image_id
# 6:19:50 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:213:1 Unused CSS selector ".dragger"
# 6:19:50 PM [vite-plugin-svelte] /Users/eyubogln/code/meerkat/meerkat/interactive/app/src/routes/interface.svelte:228:0 Unused CSS selector ".dragger:hover"

# %% [markdown]
# ## Going beyond available metadata...
#
# The trouble is, the subgroup annotations provided in RFW are quite limited. What if there are other groups that we'd like to explore for which we lack annotations?
#
# This is where things start to get interesting: we are goinng to use large, pretrained models in order to bootstrap our dataset with more metadata! This is the key idea behind Meerkat.
#
# To demonstrate this idea, we've implemented the `match` operation in the GUI. With `match`, we can create new columns by writing natural language queries and matching them to the images. For example, say we want a metadata column that tells us whether the person in the image is wearing sunglasses. We can write a query like: "A person wearing sunglasses."
#
# Let's try it out below. First, we'll need to `embed` the images into a latent space using a pretrained encoder (e.g. CLIP). Meerkat includes a registry of available encoders, so we can just specify one in the `mk.embed` call.

# %%
# In practice, columns can be embedded using `mk.embed`, however, for time's sake, we'll 
# just merge in the embeddings below
# dp = mk.embed(dp, input="image", num_workers=0, encoder="clip", device=0)

dp = dp.merge(
    mk.DataPanel.read(base_dir / "main/rfw_embedded.mk")["image_id", "clip(image)"],
    on="image_id"
)

# %%
dp.gui.table()
# Out:
#         <iframe
#             width="100%"
#             height="1000"
#             src="http://localhost:7861/interface?id=e2b4f627c37d44f399d0cfa882e7faef"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# In here.
# http://127.0.0.1:7860
# Response {
#   [Symbol(realm)]: null,
#   [Symbol(state)]: {
#     aborted: false,
#     rangeRequested: false,
#     timingAllowPassed: true,
#     requestIncludesCredentials: true,
#     type: 'default',
#     status: 200,
#     timingInfo: {
#       startTime: 9582.516708016396,
#       redirectStartTime: 9582.516708016396,
#       redirectEndTime: 9583.367250084877,
#       postRedirectStartTime: 9583.367250084877,
#       finalServiceWorkerStartTime: 0,
#       finalNetworkResponseStartTime: 0,
#       finalNetworkRequestStartTime: 0,
#       endTime: 0,
#       encodedBodySize: 0,
#       decodedBodySize: 0,
#       finalConnectionTimingInfo: null
#     },
#     cacheState: '',
#     statusText: 'OK',
#     headersList: HeadersList {
#       [Symbol(headers map)]: [Map],
#       [Symbol(headers map sorted)]: null
#     },
#     urlList: [ [URL], [URL] ],
#     body: { stream: undefined }
#   },
#   [Symbol(headers)]: HeadersList {
#     [Symbol(headers map)]: Map(4) {
#       'date' => 'Thu, 18 Aug 2022 21:22:55 GMT',
#       'server' => 'uvicorn',
#       'content-length' => '100',
#       'content-type' => 'application/json'
#     },
#     [Symbol(headers map sorted)]: null
#   }
# }
# {
#   component: 'table',
#   props: {
#     type: 'table',
#     nrows: 40528,
#     dp: '6f8701691b8444639a91fe24d893cc13'
#   }
# }
# http://127.0.0.1:7860/dp/6f8701691b8444639a91fe24d893cc13/rows
# start: 0
# end: 100
# indices: undefined
# columns: undefined
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# Matching produces a continuous score for each image in the dataset. We'd like to find a *threshold score* above which people are wearing sunglasses. Using the gallery view we can find this threshold quite easily.

# %%
dp["sunglasses"] = dp["_match_image_A person wearing sunglasses."] - dp["_match_image_A person."]
dp = dp.sort(by="sunglasses", ascending=False)
dp.gui.table()
# Out:
#         <iframe
#             width="100%"
#             height="1000"
#             src="http://localhost:7861/interface?id=8649a46396bd4e35a886691e7fc4f672"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# In here.
# http://127.0.0.1:7860
# Response {
#   [Symbol(realm)]: null,
#   [Symbol(state)]: {
#     aborted: false,
#     rangeRequested: false,
#     timingAllowPassed: true,
#     requestIncludesCredentials: true,
#     type: 'default',
#     status: 200,
#     timingInfo: {
#       startTime: 40864.37191605568,
#       redirectStartTime: 40864.37191605568,
#       redirectEndTime: 40865.6775829792,
#       postRedirectStartTime: 40865.6775829792,
#       finalServiceWorkerStartTime: 0,
#       finalNetworkResponseStartTime: 0,
#       finalNetworkRequestStartTime: 0,
#       endTime: 0,
#       encodedBodySize: 0,
#       decodedBodySize: 0,
#       finalConnectionTimingInfo: null
#     },
#     cacheState: '',
#     statusText: 'OK',
#     headersList: HeadersList {
#       [Symbol(headers map)]: [Map],
#       [Symbol(headers map sorted)]: null
#     },
#     urlList: [ [URL], [URL] ],
#     body: { stream: undefined }
#   },
#   [Symbol(headers)]: HeadersList {
#     [Symbol(headers map)]: Map(4) {
#       'date' => 'Thu, 18 Aug 2022 21:23:33 GMT',
#       'server' => 'uvicorn',
#       'content-length' => '100',
#       'content-type' => 'application/json'
#     },
#     [Symbol(headers map sorted)]: null
#   }
# }
# {
#   component: 'table',
#   props: {
#     type: 'table',
#     nrows: 40528,
#     dp: '72887d51ed3b4be7900273382bc31159'
#   }
# }
# http://127.0.0.1:7860/dp/72887d51ed3b4be7900273382bc31159/rows
# start: 0
# end: 100
# indices: undefined
# columns: undefined

# %%
dp["sunglasses"] = dp["sunglasses"] > -0.23

# %%
dp = dp.sample(frac=1, replace=False)

# %%
gb = dp.groupby(by="sunglasses")
gb["v6_fnmr"].mean()
# Out:
# DataPanel(nrows: 2, ncols: 2)

# %%
gb.gui.cards(
    main_column="image", 
    tag_columns=["v6_fnmr"],
    aggregations={
        "Mean FNMR": lambda x: x["v6_fnmr"].mean(),
        "STD FNMR": lambda x: x["v6_fnmr"].std(),
        "Size": len,
    }
)
# Out:
#         <iframe
#             width="100%"
#             height="1000"
#             src="http://localhost:7861/interface?id=dabbedf56d2d4427b5539d7a079ceb62"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# In here.
# http://127.0.0.1:7860
# Response {
#   [Symbol(realm)]: null,
#   [Symbol(state)]: {
#     aborted: false,
#     rangeRequested: false,
#     timingAllowPassed: true,
#     requestIncludesCredentials: true,
#     type: 'default',
#     status: 200,
#     timingInfo: {
#       startTime: 125846.68587505817,
#       redirectStartTime: 125846.68587505817,
#       redirectEndTime: 125848.81166601181,
#       postRedirectStartTime: 125848.81166601181,
#       finalServiceWorkerStartTime: 0,
#       finalNetworkResponseStartTime: 0,
#       finalNetworkRequestStartTime: 0,
#       endTime: 0,
#       encodedBodySize: 0,
#       decodedBodySize: 0,
#       finalConnectionTimingInfo: null
#     },
#     cacheState: '',
#     statusText: 'OK',
#     headersList: HeadersList {
#       [Symbol(headers map)]: [Map],
#       [Symbol(headers map sorted)]: null
#     },
#     urlList: [ [URL], [URL] ],
#     body: { stream: undefined }
#   },
#   [Symbol(headers)]: HeadersList {
#     [Symbol(headers map)]: Map(4) {
#       'date' => 'Thu, 18 Aug 2022 21:24:57 GMT',
#       'server' => 'uvicorn',
#       'content-length' => '360',
#       'content-type' => 'application/json'
#     },
#     [Symbol(headers map sorted)]: null
#   }
# }
# {
#   component: 'sliceby-cards',
#   props: {
#     type: 'sliceby-cards',
#     sliceby_id: '5c4ad375833e40ca88725de53794aa32',
#     datapanel_id: 'dd0b1b55141342c58a2b388a5f1e81c3',
#     main_column: 'image',
#     tag_columns: [ 'v6_fnmr' ],
#     aggregations: {
#       'Mean FNMR': '3cd52087756f476788171a60eaa70832',
#       'STD FNMR': '861f1e9db0734f3d93918bcce4ab8cda',
#       Size: '605fb741cd5b4cf8ae9af0513f28b648'
#     }
#   }
# }
# Mean FNMR
# 3cd52087756f476788171a60eaa70832
# STD FNMR
# 861f1e9db0734f3d93918bcce4ab8cda
# Size
# 605fb741cd5b4cf8ae9af0513f28b648
# {
#   'Mean FNMR': { dp: { false: ' 0.022541', true: ' 0.038014' } },
#   'STD FNMR': { dp: { false: ' 0.109713', true: ' 0.14555' } },
#   Size: { dp: { false: ' 39677', true: ' 851' } }
# }

# %%
dp.gui.table()

# %% [markdown]
# ## Discovering slices
#
# The subgroup annotations provided in RFW are quite limited, so we’ll use meerkat to *discover* new slices. To do so, we’ll use `dp.explainby`, a method that identifies a set of slices (*i.e.* scalar functions of the `by` column) that explain the variance in the response variable.

# %%
from meerkat.ops.sliceby.explainby import explainby

# dp = mk.DataPanel.read(base_dir / "themis/facecompare_v6_global_slices.mk")

indian_dp = dp.lz[dp["ethnicity"] == "indian"] 

eb = explainby(indian_dp, by="image", target="v6_fnmr",  n_slices=10, use_cache=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/eyubogln/code/meerkat/scratch/sabri/08-15-themis_demo.ipynb Cell 28' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/eyubogln/code/meerkat/scratch/sabri/08-15-themis_demo.ipynb#ch0000025?line=0'>1</a> from meerkat.ops.sliceby.explainby import explainby
#       <a href='vscode-notebook-cell:/Users/eyubogln/code/meerkat/scratch/sabri/08-15-themis_demo.ipynb#ch0000025?line=2'>3</a> # dp = mk.DataPanel.read(base_dir / "themis/facecompare_v6_global_slices.mk")
#       <a href='vscode-notebook-cell:/Users/eyubogln/code/meerkat/scratch/sabri/08-15-themis_demo.ipynb#ch0000025?line=4'>5</a> indian_dp = dp.lz[dp["ethnicity"] == "indian"]
#
# ModuleNotFoundError: No module named 'meerkat.ops.sliceby.explainby'

# %%
eb.gui.cards(
    main_column="image", 
    tag_columns=["v6_fnmr", "ethnicity"],
    aggregations={
        "Mean FNMR": lambda x: x["v6_fnmr"].mean(),
        "STD FNMR": lambda x: x["v6_fnmr"].std(),
        "Size": len,
    }
)
# Out:
#         <iframe
#             width="100%"
#             height="1000"
#             src="http://localhost:7861/interface?id=c5cb91dd39af44b39fe8588b0bdc8bb1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# In here.
# http://127.0.0.1:7860
# Response {
#   [Symbol(realm)]: null,
#   [Symbol(state)]: {
#     aborted: false,
#     rangeRequested: false,
#     timingAllowPassed: true,
#     requestIncludesCredentials: true,
#     type: 'default',
#     status: 200,
#     timingInfo: {
#       startTime: 182679.6961660385,
#       redirectStartTime: 182679.6961660385,
#       redirectEndTime: 182681.21908307076,
#       postRedirectStartTime: 182681.21908307076,
#       finalServiceWorkerStartTime: 0,
#       finalNetworkResponseStartTime: 0,
#       finalNetworkRequestStartTime: 0,
#       endTime: 0,
#       encodedBodySize: 0,
#       decodedBodySize: 0,
#       finalConnectionTimingInfo: null
#     },
#     cacheState: '',
#     statusText: 'OK',
#     headersList: HeadersList {
#       [Symbol(headers map)]: [Map],
#       [Symbol(headers map sorted)]: null
#     },
#     urlList: [ [URL], [URL] ],
#     body: { stream: undefined }
#   },
#   [Symbol(headers)]: HeadersList {
#     [Symbol(headers map)]: Map(4) {
#       'date' => 'Thu, 18 Aug 2022 21:25:54 GMT',
#       'server' => 'uvicorn',
#       'content-length' => '372',
#       'content-type' => 'application/json'
#     },
#     [Symbol(headers map sorted)]: null
#   }
# }
# {
#   component: 'sliceby-cards',
#   props: {
#     type: 'sliceby-cards',
#     sliceby_id: 'd0576819fa9e4706b9c35f320b621324',
#     datapanel_id: '297c7baaf17f400d82ea0090475989d4',
#     main_column: 'image',
#     tag_columns: [ 'v6_fnmr', 'ethnicity' ],
#     aggregations: {
#       'Mean FNMR': '96a86835506f45569bcf434724c1882d',
#       'STD FNMR': 'd123a6b0bcfb4ae49da427a61f5f9c99',
#       Size: 'fca8f39f3ea543079a8ca65cfaf49967'
#     }
#   }
# }
# Mean FNMR
# 96a86835506f45569bcf434724c1882d
# STD FNMR
# d123a6b0bcfb4ae49da427a61f5f9c99
# Size
# fca8f39f3ea543079a8ca65cfaf49967
# {
#   'Mean FNMR': {
#     dp: {
#       '0': ' 0.071018',
#       '1': ' 0.059524',
#       '2': ' 0.058559',
#       '3': ' 0.047126',
#       '4': ' 0.047401',
#       '5': ' 0.044223',
#       '6': ' 0.042954',
#       '7': ' 0.035335',
#       '8': ' 0.03347',
#       '9': ' 0.032338'
#     }
#   },
#   'STD FNMR': {
#     dp: {
#       '0': ' 0.201545',
#       '1': ' 0.157297',
#       '2': ' 0.199757',
#       '3': ' 0.187066',
#       '4': ' 0.178142',
#       '5': ' 0.155331',
#       '6': ' 0.161938',
#       '7': ' 0.147754',
#       '8': ' 0.133669',
#       '9': ' 0.124406'
#     }
#   },
#   Size: {
#     dp: {
#       '0': ' 203',
#       '1': ' 231',
#       '2': ' 74',
#       '3': ' 145',
#       '4': ' 109',
#       '5': ' 251',
#       '6': ' 1223',
#       '7': ' 383',
#       '8': ' 122',
#       '9': ' 201'
#     }
#   }
# }

# %%
indian_dp = indian_dp.sort(by="v6_fnmr", ascending=False)
cb = indian_dp.clusterby(by="image")
cb.gui.cards(
    main_column="image", 
    tag_columns=["v6_fnmr", "ethnicity"],
    aggregations={
        "Mean FNMR": lambda x: x["v6_fnmr"].mean(),
        "STD FNMR": lambda x: x["v6_fnmr"].std(),
        "Size": len,
    }
)

# %% [markdown]
# ## Diving deeper
#
# In practice, the slices discovered in the previous section should serve as inspiration for further exploration. One great way to quickly continue exploring other slices is via the plot interface. Unlike standard plotting interfaces, you can actually manipulate the axes and add labels for columns that don’t yet exist.

# %%
indian_dp.gui.table()
# Out:
#         <iframe
#             width="100%"
#             height="1000"
#             src="http://localhost:7861/interface?id=8221c948d71e4d9eac676c06249c90b0"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# In here.
# http://127.0.0.1:7860
# Response {
#   [Symbol(realm)]: null,
#   [Symbol(state)]: {
#     aborted: false,
#     rangeRequested: false,
#     timingAllowPassed: true,
#     requestIncludesCredentials: true,
#     type: 'default',
#     status: 200,
#     timingInfo: {
#       startTime: 240731.8119159937,
#       redirectStartTime: 240731.8119159937,
#       redirectEndTime: 240733.22329103947,
#       postRedirectStartTime: 240733.22329103947,
#       finalServiceWorkerStartTime: 0,
#       finalNetworkResponseStartTime: 0,
#       finalNetworkRequestStartTime: 0,
#       endTime: 0,
#       encodedBodySize: 0,
#       decodedBodySize: 0,
#       finalConnectionTimingInfo: null
#     },
#     cacheState: '',
#     statusText: 'OK',
#     headersList: HeadersList {
#       [Symbol(headers map)]: [Map],
#       [Symbol(headers map sorted)]: null
#     },
#     urlList: [ [URL], [URL] ],
#     body: { stream: undefined }
#   },
#   [Symbol(headers)]: HeadersList {
#     [Symbol(headers map)]: Map(4) {
#       'date' => 'Thu, 18 Aug 2022 21:26:52 GMT',
#       'server' => 'uvicorn',
#       'content-length' => '100',
#       'content-type' => 'application/json'
#     },
#     [Symbol(headers map sorted)]: null
#   }
# }
# {
#   component: 'table',
#   props: {
#     type: 'table',
#     nrows: 10280,
#     dp: '297c7baaf17f400d82ea0090475989d4'
#   }
# }
# http://127.0.0.1:7860/dp/297c7baaf17f400d82ea0090475989d4/rows
# start: 0
# end: 100
# indices: undefined
# columns: undefined
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
slice_idx = 0
indian_dp[f"slice_{slice_idx}"] = indian_dp["MixtureSlicer(image,v6_fnmr)"][:, slice_idx]

# %% [markdown]
# **Demo goals.** The purpose of this demo is to collect feedback on the tools we’re developing. We would like to understand how they can be made more useful for the task of auditing machine learning models. We are still in very early days, so your concerns/suggestions will inform how we move forward. So, please be candid – any and all feedback is appreciated. To help guide the discussion, we’ve included below some specific questions that are particularly front-of-mind for us, but feel free to diverge from these topics:
#
# ❓ **Questions to Guide Feedback.**
#
# *Did you learn something new about the behavior of this algorithm? Did you find slices that you would flag for bias concerns?*
#
# *Are these slices actionable? What would that action be? How would you address this slice?*
#
# *Did the slices you found seem important/interesting to you? If not, what kinds of slices do you think would be important to find?* *Why do you supect it is hard to find those slices?*
#
# Interface Questions
#
# - *Did you find the natural language descriptions useful for describing discovered slices, or did just looking through the pictures suffice? Did you trust the descriptions? Concrete examples (ideally with screenshots) would be great here.*
# - *Did you use natural language to test out new slices? What types of prompts did you write? Did you trust the results?*
# - *The main interface we currently provide for creating new slices is with natural language? Are there other interfaces you would find useful (*e.g. *scribbling, cropping, upload images)? Were there slices you would’ve liked to test, but weren’t able to?*
# - *Did you trust the statistics computed on the slices? How can we improve trust? *
#
# Implementation Questions:
#
# - *For the types of datasets you work with, do you think it would be easy to store it in a Meerkat DataPanel? Does this data structure feel like a good fit? How could it be improved to better support your data?*
# - *Are there views, plots, visualizations of the data that you were craving?*
# - *Was it easy to use Meerkat in a Jupyter Notebook?*
