# %%
import meerkat as mk

# %%
dp = mk.get("ngoa")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /root/code/meerkat/scratch/sabri/10-04_ngoa.ipynb Cell 2 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://k8s-container%2Bcontext%3Dgke_hai-gcp-fine-grained_us-west1-a_cluster-1%2Bpodname%3Dsabri-pod-dev%2Bnamespace%3Ddefault%2Bname%3Dpod-dev%2Bimage%3Dgcr.io%252fhai-gcp-fine-grained%252fdefault-small/root/code/meerkat/scratch/sabri/10-04_ngoa.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> dp = mk.get("ngoa")
#
# File /home/sabri/code/meerkat/meerkat/datasets/__init__.py:75, in get(name, dataset_dir, version, download_mode, registry, **kwargs)
#      72 for registry in registry_order:
#      73     if registry == "meerkat":
# ---> 75         dataset = datasets.get(
#      76             name=name,
#      77             dataset_dir=dataset_dir,
#      78             version=version,
# ...

# %%
dp
# Out:
# DataPanel(nrows: 13394, ncols: 13)
