# %%
import meerkat as mk

# %%
data = mk.get("ngoa")
data['published_images']
# Out:
# /Users/dilannana/Dropbox/CS191W/meerkat/meerkat/datapanel.py:436: DtypeWarning: Columns (28) have mixed types. Specify dtype option on import or set low_memory=False.
#   return cls.from_pandas(pd.read_csv(filepath, *args, **kwargs))
# DataPanel(nrows: 104505, ncols: 13)
