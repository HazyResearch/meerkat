# %%
# %load_ext autoreload
# %autoreload 2

# %%
import meerkat as mk
import numpy as np
import torch
import clip
from PIL import Image
import ray
import pandas as pd

device = "cuda" if torch.cuda.is_available() else "cpu"
model, preprocess = clip.load("ViT-B/32", device=device)

df = mk.get("imagenette", version="160px")

# %%
df["img2"] = df["img"]
df["img2"][0]()
# Out:
# <PIL.Image.Image image mode=RGB size=213x160>

# %%
out = df.defer(lambda img, img2: np.array(img.resize((100, 100)))).defer(lambda img: img + 1).map(lambda img: img.mean(), use_ray=True)
# Out:
# 2023-01-24 17:24:31,989	INFO worker.py:1370 -- Calling ray.init() again after it has already been called.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 out = df.defer(lambda img, img2: np.array(img.resize((100, 100)))).defer(lambda img: img + 1).map(lambda img: img.mean(), use_ray=True)
#
# File ~/Documents/Stanford/2022-2023 Coterm Year/1 Autumn/meerkat/meerkat/columns/abstract.py:346, in Column.map(self, function, is_batched_fn, batch_size, inputs, outputs, output_type, materialize, **kwargs)
#     333 def map(
#     334     self,
#     335     function: Callable,
#    (...)
#     342     **kwargs,
#     343 ) -> Optional[Union[Dict, List, Column]]:
#     344     from meerkat.ops.map import map
# --> 346     return map(
#     347         data=self,
#     348         function=function,
#     349         is_batched_fn=is_batched_fn,
#     350         batch_size=batch_size,
#     351         inputs=inputs,
#     352         outputs=outputs,
#     353         output_type=output_type,
#     354         materialize=materialize,
#     355         **kwargs,
#     356     )
#
# File ~/Documents/Stanford/2022-2023 Coterm Year/1 Autumn/meerkat/meerkat/ops/map.py:428, in map(data, function, is_batched_fn, batch_size, inputs, outputs, output_type, materialize, use_ray, pbar, **kwargs)
#     316 """Create a new :class:`Column` or :class:`DataFrame` by applying a
#     317 function to each row in ${data}.
#     318
#    (...)
#     415     df["ma_eligible"]
#     416 """
#     418 deferred = defer(
#     419     data=data,
#     420     function=function,
#    (...)
#     426     materialize=materialize,
#     427 )
# --> 428 return _materialize(deferred, batch_size=batch_size, pbar=pbar, use_ray=use_ray)
#
# File ~/Documents/Stanford/2022-2023 Coterm Year/1 Autumn/meerkat/meerkat/ops/map.py:473, in _materialize(data, batch_size, pbar, use_ray)
#     471 elif curr.data.kwargs:
#     472     if len(curr.data.kwargs) > 1:
# --> 473         raise ValueError("Cannot handle multiple args")
#     474     curr = curr.data.kwargs[next(iter(curr.data.kwargs))] # Get first value in args
#     475 else:
#
# ValueError: Cannot handle multiple args
